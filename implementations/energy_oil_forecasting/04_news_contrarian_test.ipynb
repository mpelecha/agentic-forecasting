# %% [markdown]
# # WTI Crude Oil Price Forecasting — Stateless Methods: Systematic Backtest (Notebook 4 of 7)
#
# This notebook simulates a rigorous production forecasting workflow:
#
# 1. Run a **rolling weekly backtest across 2025** using
#    `energy_oil_backtest.yaml` for all candidate predictors.
# 2. Compute metrics — **CRPS** for 5/10/21-day trajectories.
# 3. Select the **top contender configurations** based solely on 2025
#    historical performance (no peeking at 2026).
# 4. Let the contenders compete in the **2026 Protected Arena**
#    (`energy_oil_eval.yaml`) across the geopolitical price shock and its
#    aftermath — measuring adaptive real-time responsiveness and calibration.
#    The eval window runs through the most recent origin whose 21-business-day
#    horizon still resolves against cached data (see `scripts/fetch_wti.py`).
#
# The line-up spans three families behind one `Predictor` interface: **baselines**
# (Naive, AutoARIMA), **numerical ML** (LightGBM ± a leak-safe covariate panel),
# and **LLM/agent** methods (LLM-process forecasters and a news-reading analyst
# agent) — the last run on *both* project models, `gemini-3.1-flash-lite-preview`
# and `gemini-3.5-flash`. Every predictor is one toggle line in the registry in
# Section 2. Agent configs come from `energy_oil_forecasting.analyst_agent`.

# %% [markdown]
# ---
# ## 1. Setup, Data Registration & Spec Loading

# %%
import warnings
from pathlib import Path

import energy_oil_forecasting
import pandas as pd
import yaml
from aieng.forecasting.evaluation import (
    MultiTargetBacktestSpec,
    cached_multi_backtest,
    describe_spec,
)
from aieng.forecasting.models import ADVANCED_MODEL, LITE_MODEL
from energy_oil_forecasting.data import (
    DEFAULT_WTI_COVARIATE_SERIES_IDS,
    build_wti_multivariate_service,
)

from energy_oil_forecasting.scenario_schema_anchored import (
    build_wti_news_scenario_schema_anchored_config,
    build_wti_scenario_schema_anchored_predictor,
)


warnings.filterwarnings("ignore")

# ── Mode ──────────────────────────────────────────────────────────────────────
# Set SMOKE_TEST = True to run a 2-origin, 1-sample version of the notebook
# for fast local development and end-to-end CI testing. The full specs run
# 51 backtest + 8 eval origins; smoke runs 2 + 2.
SMOKE_TEST = False 

# ── Models ────────────────────────────────────────────────────────────────────
# The project standardises on two Vector-proxy models. Every LLM and agent
# predictor below is run once per model so we can compare them head-to-head.
# (bare proxy names — no "gemini/" prefix)
MODELS = [LITE_MODEL, ADVANCED_MODEL]  # "gemini-3.1-flash-lite-preview", "gemini-3.5-flash"

# ── Derived settings (do not edit below) ─────────────────────────────────────
N_SAMPLES = 1 if SMOKE_TEST else 3  # trajectories per LLMP-Sampled call

# LightGBM hyperparameters (shared by the univariate and +covariate variants).
LAGS = 21  # one trading month of lagged target/covariate history
NUM_SAMPLES_LGBM = 100 if SMOKE_TEST else 200  # Monte-Carlo draws for quantiles
LGBM_KWARGS = {"num_threads": 1, "n_jobs": 1, "verbosity": -1}  # deterministic, quiet

# Data service: WTI target + a leak-safe covariate panel (all Yahoo Finance —
# Brent, natural gas, gasoline, gold, USD index, the USL/USO futures-curve
# contango proxy, and VIX). Non-covariate predictors simply ignore the extras,
# so one service feeds the whole leaderboard. Unavailable tickers are skipped
# with a warning, so this still runs offline / under partial connectivity.
data_service = build_wti_multivariate_service()
COVARIATES = [c for c in DEFAULT_WTI_COVARIATE_SERIES_IDS if c in set(data_service.series_ids)]

spec_dir = Path(energy_oil_forecasting.__file__).parent / "specs"
if SMOKE_TEST:
    backtest_file, eval_file = "energy_oil_smoke.yaml", "energy_oil_eval_smoke.yaml"
else:
    backtest_file, eval_file = "energy_oil_backtest.yaml", "energy_oil_eval.yaml"

with open(spec_dir / backtest_file) as f:
    backtest_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))
with open(spec_dir / eval_file) as f:
    eval_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))



# ── Reduce origin frequency + give this window its own cache namespace ─────
# spec_id now depends on SMOKE_TEST too, so toggling smoke/full never collides
# with (or silently reuses) the other mode's cached results.
_suffix = "_smoke" if SMOKE_TEST else ""

#backtest_spec.stride = 21  # ~monthly → ~12 origins instead of 51 (full mode)
backtest_spec.stride = 10  # ~biweekly → ~26 origins instead of 51 (full mode)
backtest_spec.spec_id = f"energy_oil_backtest_biweekly{_suffix}"

#eval_spec.stride = 21      # ~monthly → ~5 origins instead of 18 (full mode)
eval_spec.stride = 10      # ~biweekly → ~9 origins instead of 18 (full mode)
eval_spec.spec_id = f"energy_oil_eval_biweekly{_suffix}"





print(f"{'⚡ SMOKE MODE' if SMOKE_TEST else '📊 FULL MODE'} — MODELS={MODELS}  N_SAMPLES={N_SAMPLES}")
print(f"Covariates registered ({len(COVARIATES)}): {', '.join(COVARIATES) or '(none)'}")
print()
print("━" * 72)
print("LOADED SPECIFICATIONS:")
print("━" * 72)
print(describe_spec(backtest_spec, data_service))
print(describe_spec(eval_spec, data_service))
# Out:
# 📊 FULL MODE — MODELS=['gemini-3.1-flash-lite-preview', 'gemini-3.5-flash']  N_SAMPLES=3
# Covariates registered (7): brent_log_ret_1b_l1b, natgas_log_ret_1b_l1b, gasoline_log_ret_1b_l1b, gold_log_ret_1b_l1b, dollar_index_log_ret_1b_l1b, oil_curve_contango_l1b, vix_level_l1b
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# LOADED SPECIFICATIONS:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MultiTargetBacktestSpec (spec_id=energy_oil_backtest_biweekly)
#   description: Weekly rolling backtest in 2025 for daily WTI crude oil price forecasting. Evaluates trajectory forecasts (5, 10, 21 business days) with CRPS/MAE and binary up-shock forecasts (climb > $5 in 5 business days) with Brier Score. Used to select the top contender models.
#   start:       2025-01-06 00:00:00
#   end:         2025-12-22 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B
#
# MultiTargetBacktestSpec (spec_id=energy_oil_eval_biweekly)
#   description: Prospective/out-of-sample evaluation period in 2026 for daily WTI crude oil. Evaluates selected contender models on 18 weekly origins from the early 2026 geopolitical price shock through its aftermath, to measure adaptive real-time forecasting performance.
#   start:       2026-02-02 00:00:00
#   end:         2026-06-01 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B

# %% [markdown]
# ---
# ## 2. Candidate Predictors
#
# This experiment puts a full slate of methods on the same `Predictor` interface and
# the same rolling backtest, spanning three families:
#
# | Family | Predictors | Role |
# |---|---|---|
# | **Baselines** | `Naive (Last Value)`, `AutoARIMA` | Carry-forward floor + the classical statistical anchor |
# | **Numerical ML** | `LightGBM`, `LightGBM + cov` (+ optional `Prophet`) | Gradient-boosted quantile regression on lagged price (and a leak-safe covariate panel — Brent, gas, gasoline, gold, USD index, the futures-curve contango proxy, and VIX). LightGBM-with-covariates was the strongest method in the S&P 500 study. |
# | **LLM / Agent** | `LLMP-Sampled`, `LLMP-Grid`, `News Agent` — each on **both** project models | LLM-process forecasters and a news-reading analyst agent, run on `gemini-3.1-flash-lite-preview` *and* `gemini-3.5-flash` |
#
# The predictor cell below is a **registry**: every method is one line with an
# `enabled` flag. Flip a flag to add or drop a predictor — the rest of the
# notebook (backtest, scoring, eval, scorecard) iterates over whatever is active.
# The two baselines are flagged `baseline=True` and are the only results written to
# `adaptive_agent/curriculum/` for Notebooks 5–6, so toggling the others never
# disturbs the downstream training data.

# %%
from dataclasses import dataclass
from typing import Callable

from aieng.forecasting.methods import (
    LastValuePredictor,
    QuantileGridLLMPredictor,
    QuantileGridLLMPredictorConfig,
    SampledTrajectoryLLMPredictor,
    SampledTrajectoryLLMPredictorConfig,
)
from aieng.forecasting.methods.numerical.darts_arima import DartsAutoARIMAPredictor
from aieng.forecasting.methods.numerical.darts_regression import DartsLightGBMPredictor
from energy_oil_forecasting.analyst_agent import (
    build_wti_agent_predictor,
    build_wti_news_config,
    build_wti_news_contrarian_config,
    build_wti_news_factors_v2_config,
    build_wti_news_scenario_schema_config,
    build_wti_scenario_schema_predictor,
)
from energy_oil_forecasting.cfm_agent_v_5_2 import (
    build_cfm_agent_config,
    build_cfm_agent_predictor,
)
from energy_oil_forecasting.prophet_baseline import ProphetPredictor


@dataclass
class PredictorEntry:
    """One row in the experiment. Flip ``enabled`` to switch a predictor on/off."""

    name: str
    factory: Callable[[], object]  # lazy — built only when enabled
    enabled: bool = True
    baseline: bool = False  # baselines are saved to curriculum/ for NB05–06


# LLM / agent factories — each takes a model so the same recipe runs on both.
# LLMP-Sampled optionally serializes the covariate panel into the prompt
# (labeled exogenous-series blocks); the others are target-only. A distinct
# variant_tag keeps the +cov run separate in the cache and on the leaderboard.
def _llmp_sampled(model, covariates=None):
    return SampledTrajectoryLLMPredictor(
        SampledTrajectoryLLMPredictorConfig(
            model=model,
            n_samples=N_SAMPLES,
            covariate_series_ids=covariates,
            variant_tag="cov" if covariates else None,
        )
    )


def _llmp_grid(model):
    return QuantileGridLLMPredictor(QuantileGridLLMPredictorConfig(model=model))


#def _news_agent(model):
#    return build_wti_agent_predictor(build_wti_news_config(model=model))


#def _news_agent_contrarian(model):
#    return build_wti_agent_predictor(build_wti_news_contrarian_config(model=model))


def _news_agent(model):
    return build_wti_agent_predictor(
        build_wti_news_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                              )
    )


def _news_agent_contrarian(model):
    return build_wti_agent_predictor(
        build_wti_news_contrarian_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )


def _news_agent_factors_v2(model):
    return build_wti_agent_predictor(
        build_wti_news_factors_v2_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )

def _news_agent_scenario_schema(model):
    return build_wti_scenario_schema_predictor(
        build_wti_news_scenario_schema_config(model=model)
    )


def _news_agent_scenario_schema_zero_temp(model: str):
    """News Scenario Schema with temperature=0 for consistency testing."""
    print("🔥 Creating NEWS AGENT with temperature=0.0")  # ← ADD THIS
    config = build_wti_news_scenario_schema_config(
        model=model, 
        temperature=0.0
    )
    return build_wti_scenario_schema_predictor(config)

def _news_agent_scenario_schema_enhanced(model):
    from energy_oil_forecasting.scenario_schema_enhanced import (
        build_wti_news_scenario_schema_enhanced_config,
        build_wti_scenario_schema_enhanced_predictor,
    )
    config = build_wti_news_scenario_schema_enhanced_config(model=model)
    return build_wti_scenario_schema_enhanced_predictor(config)


def _news_agent_scenario_schema_anchored(model):
    config = build_wti_news_scenario_schema_anchored_config(model=model)
    return build_wti_scenario_schema_anchored_predictor(config)

    
def _cfm_agent_v_5_2():
    config = build_cfm_agent_config()
    return build_cfm_agent_predictor(config)

def _cfm_agent_v_5_2_arima_only():
    from energy_oil_forecasting.cfm_agent_v_5_2 import (
        build_cfm_agent_config_arima_only,
        build_cfm_agent_predictor_arima_only,
    )
    config = build_cfm_agent_config_arima_only()
    return build_cfm_agent_predictor_arima_only(config)



# ── Experiment registry ───────────────────────────────────────────────────────
# Toggle `enabled` on any line to include/exclude that predictor. LLM and agent
# methods are listed once per model so each can be switched on/off individually.
REGISTRY = [
    # Baselines — always saved to curriculum/ for the adaptive-agent notebooks.
    PredictorEntry("Naive (Last Value)", LastValuePredictor, enabled=True, baseline=True),
    PredictorEntry("AutoARIMA", DartsAutoARIMAPredictor, enabled=True, baseline=True),
    # Numerical ML — LightGBM was the strongest method in the S&P 500 study.
    PredictorEntry(
        "LightGBM",
        lambda: DartsLightGBMPredictor(lags=LAGS, num_samples=NUM_SAMPLES_LGBM, lgbm_kwargs=LGBM_KWARGS),
        enabled=False,
    ),
    PredictorEntry(
        "LightGBM + cov",
        lambda: DartsLightGBMPredictor(
            lags=LAGS,
            lags_past_covariates=LAGS,
            covariate_series_ids=COVARIATES,
            num_samples=NUM_SAMPLES_LGBM,
            lgbm_kwargs=LGBM_KWARGS,
        ),
        enabled=False,
    ),
    PredictorEntry("Prophet", ProphetPredictor, enabled=False),
    # LLM processes and the news agent — one row per model in MODELS.
    PredictorEntry(f"LLMP-Sampled ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Sampled ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL), enabled=False),
    # LLMP-Sampled with the covariate panel serialized into the prompt — the one
    # LLM method that can take covariates with no package change. Compare each of
    # these against its target-only twin above to see if context helps the LLM.
    PredictorEntry(f"LLMP-Sampled + cov ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL, COVARIATES), enabled=False),
    PredictorEntry(
        f"LLMP-Sampled + cov ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL, COVARIATES), enabled=False
    ),
    PredictorEntry(f"LLMP-Grid ({LITE_MODEL})", lambda: _llmp_grid(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Grid ({ADVANCED_MODEL})", lambda: _llmp_grid(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({LITE_MODEL})", lambda: _news_agent(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({ADVANCED_MODEL})", lambda: _news_agent(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent Contrarian ({LITE_MODEL})", lambda: _news_agent_contrarian(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Factors V2 ({LITE_MODEL})", lambda: _news_agent_factors_v2(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Scenario Schema ({LITE_MODEL})", lambda: _news_agent_scenario_schema(LITE_MODEL), enabled=True),
    PredictorEntry(f"News Agent Scenario Schema - zero temp ({LITE_MODEL})", 
                   lambda: _news_agent_scenario_schema_zero_temp(LITE_MODEL), 
                   enabled=False),
    PredictorEntry(f"News Agent Scenario Schema Enhanced - temp=0 ({LITE_MODEL})", 
                   lambda: _news_agent_scenario_schema_enhanced(LITE_MODEL), 
                    enabled=True),

    PredictorEntry(f"News Agent Scenario Schema Anchored ({LITE_MODEL})", 
               lambda: _news_agent_scenario_schema_anchored(LITE_MODEL), 
               enabled=True),

               
    PredictorEntry("CFM Agent v5.2", _cfm_agent_v_5_2, enabled=True),
    PredictorEntry("CFM Agent v5.2.2 (ARIMA only)", _cfm_agent_v_5_2_arima_only, enabled=True),

    

]

# Instantiate only the enabled predictors (lazy factories skip the rest).
PREDICTORS = {e.name: e.factory() for e in REGISTRY if e.enabled}
_BASELINE_PREDICTORS = {e.name for e in REGISTRY if e.baseline}

print(f"Active predictors ({len(PREDICTORS)}):")
for name in PREDICTORS:
    tag = "  (baseline → curriculum/)" if name in _BASELINE_PREDICTORS else ""
    print(f"  {name}{tag}")
# Out:
# Active predictors (7):
#   Naive (Last Value)  (baseline → curriculum/)
#   AutoARIMA  (baseline → curriculum/)
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview)
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)
#   CFM Agent v5.2
#   CFM Agent v5.2.2 (ARIMA only)

# %% [markdown]
# ---
# ## 3. Run the 2025 Historical Backtest
#
# All 51 weekly origins in 2025 are evaluated for each predictor.
# `cached_multi_backtest` caches results under `data/predictions/` so
# subsequent runs are instant.

# %%
import time

print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
print("LLM/agent runs are expensive — first run will take several minutes.\n")

backtest_results: dict[str, object] = {}
for i, (_name, _predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)  # pace between predictors, not just after a failure
    backtest_results[_name] = cached_multi_backtest(
        _predictor, backtest_spec, data_service,
        max_retries=4,     # was 2
        retry_delay=30.0,  # was 2.0 — long enough to clear an RPM window
        force_refresh=False, #(_name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {_name} ✓")

print("\nAll 2025 backtests complete.")

#print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
#print("LLM/agent runs are expensive — first run will take several minutes.\n")
#
#backtest_results: dict[str, object] = {}
#for _name, _predictor in PREDICTORS.items():
#    backtest_results[_name] = cached_multi_backtest(_predictor, backtest_spec, data_service)
#    print(f"  {_name} ✓")
#
#print("\nAll 2025 backtests complete.")
# Out:
# Running 2025 rolling backtest (7 predictor(s))...
# LLM/agent runs are expensive — first run will take several minutes.
#
#   Naive (Last Value) ✓
#   AutoARIMA ✓
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview) ✓
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview) ✓
#   CFM Agent v5.2 ✓
#   CFM Agent v5.2.2 (ARIMA only) ✓
#
# All 2025 backtests complete.

# %% [markdown]
# ---
# ## 4. Performance Characterisation
#
# We score every active predictor on the 2025 backtest data:
# - **CRPS** (Continuous Ranked Probability Score) — sharpness + calibration combined
# - **MAE at h=21d** — point forecast accuracy at the longest horizon
#
# The leaderboard ranks the families against each other — how much structure the
# numerical methods (AutoARIMA, LightGBM ± covariates) extract over the naive
# floor, whether the covariate panel earns its keep, and how the LLM/agent methods
# compare across the two models. Where each method wins and where it struggles in
# 2025 is exactly the material the adaptive agent learns from in Notebook 5.

# %%
import math

from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []
for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    leaderboard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS": scores.get("mean_crps", float("nan")),
            "MAE h=21d": scores.get("mae_h21", float("nan")),
        }
    )

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print("2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:")
print("━" * 72)
print(df_leaderboard.to_string())

arima_crps = df_leaderboard.loc["AutoARIMA", "Mean CRPS"] if "AutoARIMA" in df_leaderboard.index else float("nan")
naive_crps = (
    df_leaderboard.loc["Naive (Last Value)", "Mean CRPS"]
    if "Naive (Last Value)" in df_leaderboard.index
    else float("nan")
)
if not math.isnan(arima_crps):
    print(
        f"\nAutoARIMA CRPS improvement over Naive: {naive_crps - arima_crps:.4f} ({(naive_crps - arima_crps) / naive_crps:.1%})"
    )
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     2.023526   2.750811
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   2.032458   2.762162
# CFM Agent v5.2                                                                 2.122313   2.859812
# CFM Agent v5.2.2 (ARIMA only)                                                  2.489864   3.014870
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            2.501722   2.977707
# AutoARIMA                                                                      2.504927   3.007586
# Naive (Last Value)                                                             3.002162   3.002162
#
# AutoARIMA CRPS improvement over Naive: 0.4972 (16.6%)

# %%
import math
import numpy as np
import pandas as pd
from datetime import datetime
from aieng.forecasting.evaluation.prediction import ContinuousForecast
from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []

for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    
    # Per-horizon MAE breakdown (instead of blended mae_h21)
    horizon_errors: dict[int, list[float]] = {h: [] for h in backtest_spec.tasks[0].horizons}
    for result in results.values():
        task = result.spec.task
        offset = pd.tseries.frequencies.to_offset(task.frequency)
        actual_df = data_service.get_series(task.target_series_id, as_of=datetime.now())
        actual_by_date = {
            pd.Timestamp(row["timestamp"]).normalize(): float(row["value"]) for _, row in actual_df.iterrows()
        }
        for pred in result.predictions:
            if not isinstance(pred.payload, ContinuousForecast):
                continue
            fd = pd.Timestamp(pred.forecast_date).normalize()
            actual = actual_by_date.get(fd)
            if actual is None:
                continue
            as_of = pd.Timestamp(pred.as_of)
            for h in task.horizons:
                if (as_of + offset * h).normalize() == fd:
                    horizon_errors[h].append(abs(pred.payload.point_forecast - actual))
                    break

    row = {
        "Predictor": name,
        "Mean CRPS": scores.get("mean_crps", float("nan")),
        "80% CI Coverage": scores.get("coverage_80", float("nan")),
    }
    for h in backtest_spec.tasks[0].horizons:
        errs = horizon_errors[h]
        row[f"MAE h={h}d"] = float(np.mean(errs)) if errs else float("nan")
    leaderboard_rows.append(row)

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print(f"2025 BACKTEST — PERFORMANCE BY HORIZON:")
print("━" * 72)
print(df_leaderboard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 BACKTEST — PERFORMANCE BY HORIZON:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS  80% CI Coverage  MAE h=5d  MAE h=10d  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     2.023526        70.270270  2.603462   2.508636   3.103077
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   2.032458        70.270270  2.684231   2.689545   2.901538
# CFM Agent v5.2                                                                 2.122313        85.135135  2.735887   2.603968   3.200219
# CFM Agent v5.2.2 (ARIMA only)                                                  2.489864        93.243243  2.812114   2.749735   3.441971
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            2.501722        93.243243  2.776921   2.712050   3.403281
# AutoARIMA                                                                      2.504927        91.891892  2.829270   2.800086   3.361480
# Naive (Last Value)                                                             3.002162         0.000000  2.750770   2.741364   3.474231

# %%
# ── Save backtest results for NB05 / NB06 ────────────────────────────────────
# Only the baseline predictors (flagged in the registry above) are written to
# curriculum/ so that toggling the other predictors on/off does not change the
# files NB05 and NB06 depend on.
_CURRICULUM_DIR = Path("adaptive_agent/curriculum")
_CURRICULUM_DIR.mkdir(exist_ok=True)
for _name, _result_dict in backtest_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"backtest_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in backtest_results)} backtest result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 backtest result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 5. 2026 Evaluation — Held-Out Test Period
#
# We run every active predictor on **18 weekly origins spanning Feb–Jun 2026**
# (`energy_oil_eval.yaml`) — the major geopolitical volatility spike not seen
# during the 2025 backtest, plus its aftermath. The window runs through the
# most recent origin that still fully resolves against cached WTI data (the
# 21-business-day horizon needs data 21 business days past the origin).
#
# This evaluation serves two purposes:
# 1. **Measure out-of-sample robustness** — do the 2025 edges (statistical,
#    covariate, or LLM/agent) hold under a structural regime shift?
# 2. **Establish the stateless baseline** that the trained adaptive agents in
#    Notebook 6 are compared against. The baseline predictors' results are saved
#    to `adaptive_agent/curriculum/` for Notebooks 5 and 6 to load.

# %%
import time

print("Running 2026 evaluation...")
eval_results: dict[str, object] = {}
for i, (name, predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)
    eval_results[name] = cached_multi_backtest(
        predictor, eval_spec, data_service,
        max_retries=4,
        retry_delay=30.0,
        force_refresh=False, #(name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {name} ✓")

print("\n2026 evaluation complete.")

#print("Running 2026 evaluation...")
#eval_results: dict[str, object] = {}
#for name, predictor in PREDICTORS.items():
#    eval_results[name] = cached_multi_backtest(predictor, eval_spec, data_service)
#    print(f"  {name} ✓")

#print("\n2026 evaluation complete.")
# Out:
# Running 2026 evaluation...
#   Naive (Last Value) ✓
#   AutoARIMA ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 74.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 69.0 },
#         { "quantile": 0.1, "value": 71.0 },
#         { "quantile": 0.2, "value": 72.5 },
#         { "quantile": 0.3, "value": 73.5 },
#         { "quantile": 0.4, "value": 74.0 },
#         { "quantile": 0.5, "value": 74.5 },
#         { "quantile": 0.6, "value": 75.5 },
#         { "quantile": 0.7, "value": 77.0 },
#         { "quantile": 0.8, "value": 79.0 },
#         { "quantile": 0.9, "value": 82.0 },
#         { "quantile": 0.95, "value": 85.0 }
#       ],
#       "rationale": "Over the 5-day horizon, the market is highly reactive to the US-Iran geopolitical tension. Given the extreme sensitivity, volatility remains elevated, with price action dominated by breaking news regarding the Strait of Hormuz. A slight consolidation from the recent rally is possible if diplomacy gains traction, but risks remain heavily skewed to the upside."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 72.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 65.0 },
#         { "quantile": 0.1, "value": 67.5 },
#         { "quantile": 0.2, "value": 69.5 },
#         { "quantile": 0.3, "value": 70.5 },
#         { "quantile": 0.4, "value": 71.5 },
#         { "quantile": 0.5, "value": 72.0 },
#         { "quantile": 0.6, "value": 73.5 },
#         { "quantile": 0.7, "value": 75.0 },
#         { "quantile": 0.8, "value": 78.0 },
#         { "quantile": 0.9, "value": 83.0 },
#         { "quantile": 0.95, "value": 88.0 }
#       ],
#       "rationale": "By 10 days out, the initial shock premium may begin to stabilize or face mean reversion unless a kinetic event occurs. The range expands as the uncertainty of the US-Iran standoff either crystallizes into a conflict or yields to diplomatic de-escalation."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 69.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 60.0 },
#         { "quantile": 0.1, "value": 63.0 },
#         { "quantile": 0.2, "value": 65.0 },
#         { "quantile": 0.3, "value": 67.0 },
#         { "quantile": 0.4, "value": 68.0 },
#         { "quantile": 0.5, "value": 69.0 },
#         { "quantile": 0.6, "value": 71.0 },
#         { "quantile": 0.7, "value": 73.0 },
#         { "quantile": 0.8, "value": 76.0 },
#         { "quantile": 0.9, "value": 81.0 },
#         { "quantile": 0.95, "value": 89.0 }
#       ],
#       "rationale": "At the 21-day horizon, the fundamental pressures (structural oversupply) compete more aggressively with the geopolitical risk. If the status quo holds without a physical disruption, prices likely drift lower towards historical trend levels as the market becomes 'numb' to the ongoing tension."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Structural Oversupply",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Geopolitical Risk (Strait of Hormuz)",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "De-escalation & Fundamental Normalization",
#       "probability": 0.4,
#       "price_low": 60.0,
#       "price_high": 68.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Structural Oversupply": "bearish",
#         "Geopolitical Risk (Strait of Hormuz)": "bearish"
#       }
#     },
#     {
#       "name": "Standoff Persists",
#       "probability": 0.45,
#       "price_low": 68.0,
#       "price_high": 75.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Structural Oversupply": "bearish",
#         "Geopolitical Risk (Strait of Hormuz)": "neutral"
#       }
#     },
#     {
#       "name": "Supply Disruption (Kinetic Conflict)",
#       "probability": 0.15,
#       "price_low": 80.0,
#       "price_high": 105.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Structural Oversupply": "bearish",
#         "Geopolitical Risk (Strait of Hormuz)": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently bifurcated between structural bearishness (oversupply concerns) and extreme transitory upside risk (Strait of Hormuz tensions). Our forecasts reflect that if no physical disruption occurs, prices are prone to mean reversion, but the potential for a tail event justifies maintaining significant width in the higher quantiles."
# }
# predict() failed at origin 2026-03-02 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'... the higher quantiles.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 102.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 92.0 },
#         { "quantile": 0.1, "value": 95.0 },
#         { "quantile": 0.2, "value": 98.0 },
#         { "quantile": 0.3, "value": 100.0 },
#         { "quantile": 0.4, "value": 101.5 },
#         { "quantile": 0.5, "value": 102.5 },
#         { "quantile": 0.6, "value": 103.5 },
#         { "quantile": 0.7, "value": 105.0 },
#         { "quantile": 0.8, "value": 108.0 },
#         { "quantile": 0.9, "value": 112.0 },
#         { "quantile": 0.95, "value": 118.0 }
#       ],
#       "rationale": "Over the next 5 business days, extreme volatility is expected to persist as markets react to the immediate closure of the Strait of Hormuz. The upward bias is extreme, but capped by the psychological $110-120 range as IEA emergency stocks begin to flow."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 98.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 85.0 },
#         { "quantile": 0.1, "value": 88.0 },
#         { "quantile": 0.2, "value": 92.0 },
#         { "quantile": 0.3, "value": 95.0 },
#         { "quantile": 0.4, "value": 96.5 },
#         { "quantile": 0.5, "value": 98.0 },
#         { "quantile": 0.6, "value": 100.0 },
#         { "quantile": 0.7, "value": 103.0 },
#         { "quantile": 0.8, "value": 106.0 },
#         { "quantile": 0.9, "value": 110.0 },
#         { "quantile": 0.95, "value": 115.0 }
#       ],
#       "rationale": "By the 10-day horizon, the initial panic premium begins to erode slightly as the scale of the coordinated IEA supply response becomes clearer to physical market participants."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 92.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 78.0 },
#         { "quantile": 0.1, "value": 82.0 },
#         { "quantile": 0.2, "value": 86.0 },
#         { "quantile": 0.3, "value": 89.0 },
#         { "quantile": 0.4, "value": 90.5 },
#         { "quantile": 0.5, "value": 92.0 },
#         { "quantile": 0.6, "value": 94.0 },
#         { "quantile": 0.7, "value": 97.0 },
#         { "quantile": 0.8, "value": 100.0 },
#         { "quantile": 0.9, "value": 105.0 },
#         { "quantile": 0.95, "value": 110.0 }
#       ],
#       "rationale": "At the 21-day horizon, the market begins to focus on the medium-term structural surplus and the impact of the stock release, leading to a moderate cooling of the initial price spike."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Structural Surplus",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Strait of Hormuz Conflict",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "IEA Emergency Stock Release",
#       "category": "macro",
#       "tier": "transitory",
#       "impact_score": "high"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Controlled De-escalation",
#       "probability": 0.6,
#       "price_low": 85.0,
#       "price_high": 95.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Structural Surplus": "bullish",
#         "Strait of Hormuz Conflict": "neutral",
#         "IEA Emergency Stock Release": "bearish"
#       }
#     },
#     {
#       "name": "Prolonged Blockade",
#       "probability": 0.3,
#       "price_low": 105.0,
#       "price_high": 125.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Structural Surplus": "neutral",
#         "Strait of Hormuz Conflict": "bullish",
#         "IEA Emergency Stock Release": "bearish"
#       }
#     },
#     {
#       "name": "Global Financial Liquidity Crunch",
#       "probability": 0.1,
#       "price_low": 60.0,
#       "price_high": 75.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Structural Surplus": "bearish",
#         "Strait of Hormuz Conflict": "neutral",
#         "IEA Emergency Stock Release": "bearish"
#       }
#     }
#   ],
#   "rationale": "The market is currently undergoing an acute geopolitical shock following the closure of the Strait of Hormuz. The baseline expectation is a price spike driven by immediate supply scarcity, followed by a gradual decline as the massive IEA emergency stock release hits the market and the initial geopolitical panic modulates. Risks remain heavily skewed to the upside if the conflict widens, but a severe tail-case of a broader financial shock remains possible."
# }
# predict() failed at origin 2026-03-16 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...hock remains possible.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 68.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 64.0 },
#         { "quantile": 0.1, "value": 65.5 },
#         { "quantile": 0.2, "value": 66.5 },
#         { "quantile": 0.3, "value": 67.5 },
#         { "quantile": 0.4, "value": 68.0 },
#         { "quantile": 0.5, "value": 68.5 },
#         { "quantile": 0.6, "value": 69.5 },
#         { "quantile": 0.7, "value": 70.5 },
#         { "quantile": 0.8, "value": 72.0 },
#         { "quantile": 0.9, "value": 74.0 },
#         { "quantile": 0.95, "value": 76.0 }
#       ],
#       "rationale": "Short-term price action is dominated by the geopolitical risk premium related to US-Iran tensions. The 5-day horizon reflects high volatility as the market reacts to daily diplomatic headlines."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 69.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 62.0 },
#         { "quantile": 0.1, "value": 64.0 },
#         { "quantile": 0.2, "value": 66.0 },
#         { "quantile": 0.3, "value": 67.5 },
#         { "quantile": 0.4, "value": 68.5 },
#         { "quantile": 0.5, "value": 69.5 },
#         { "quantile": 0.6, "value": 71.0 },
#         { "quantile": 0.7, "value": 73.0 },
#         { "quantile": 0.8, "value": 75.0 },
#         { "quantile": 0.9, "value": 78.0 },
#         { "quantile": 0.95, "value": 82.0 }
#       ],
#       "rationale": "Over 10 days, the potential for either a de-escalation (leading to profit-taking) or a material escalation (Strait of Hormuz disruption) widens the distribution significantly."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 71.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 60.0 },
#         { "quantile": 0.1, "value": 63.0 },
#         { "quantile": 0.2, "value": 65.5 },
#         { "quantile": 0.3, "value": 68.0 },
#         { "quantile": 0.4, "value": 69.5 },
#         { "quantile": 0.5, "value": 71.0 },
#         { "quantile": 0.6, "value": 73.0 },
#         { "quantile": 0.7, "value": 76.0 },
#         { "quantile": 0.8, "value": 79.0 },
#         { "quantile": 0.9, "value": 84.0 },
#         { "quantile": 0.95, "value": 88.0 }
#       ],
#       "rationale": "By 21 days, the market will likely have resolved the immediate binary outcome of the current geopolitical standoff, leading to either a return to fundamental supply/demand pricing or a sustained higher regime."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Supply/Demand Balance",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "US-Iran Geopolitical Tensions",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Diplomatic De-escalation",
#       "probability": 0.4,
#       "price_low": 58.0,
#       "price_high": 65.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply/Demand Balance": "bearish",
#         "US-Iran Geopolitical Tensions": "bearish"
#       }
#     },
#     {
#       "name": "Status Quo / Continued Tension",
#       "probability": 0.45,
#       "price_low": 66.0,
#       "price_high": 72.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply/Demand Balance": "neutral",
#         "US-Iran Geopolitical Tensions": "neutral"
#       }
#     },
#     {
#       "name": "Strait of Hormuz Disruption",
#       "probability": 0.15,
#       "price_low": 80.0,
#       "price_high": 100.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Supply/Demand Balance": "bullish",
#         "US-Iran Geopolitical Tensions": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently in a high-stakes binary state driven by geopolitical risk. While physical fundamentals (oversupply) suggest lower prices, the risk of a supply shock in the Middle East is providing a significant floor and upside potential. The forecast reflects this uncertainty, with a wide distribution for longer horizons."
# }
# predict() failed at origin 2026-03-02 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...n for longer horizons.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview) ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 65.2,
#       "quantiles": [
#         { "quantile": 0.05, "value": 61.5 },
#         { "quantile": 0.1, "value": 62.5 },
#         { "quantile": 0.2, "value": 63.5 },
#         { "quantile": 0.3, "value": 64.2 },
#         { "quantile": 0.4, "value": 64.8 },
#         { "quantile": 0.5, "value": 65.2 },
#         { "quantile": 0.6, "value": 65.8 },
#         { "quantile": 0.7, "value": 66.5 },
#         { "quantile": 0.8, "value": 67.5 },
#         { "quantile": 0.9, "value": 68.5 },
#         { "quantile": 0.95, "value": 69.5 }
#       ],
#       "rationale": "Short-term price action is dominated by the tug-of-war between structural oversupply and geopolitical risk. The recent move to $65.20 reflects a consolidation phase where the market is pricing in a risk premium for Middle East tensions while acknowledging the bearish long-term supply outlook."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 64.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 59.0 },
#         { "quantile": 0.1, "value": 60.5 },
#         { "quantile": 0.2, "value": 62.0 },
#         { "quantile": 0.3, "value": 63.0 },
#         { "quantile": 0.4, "value": 63.8 },
#         { "quantile": 0.5, "value": 64.5 },
#         { "quantile": 0.6, "value": 65.2 },
#         { "quantile": 0.7, "value": 66.0 },
#         { "quantile": 0.8, "value": 67.5 },
#         { "quantile": 0.9, "value": 69.0 },
#         { "quantile": 0.95, "value": 70.5 }
#       ],
#       "rationale": "Over the 10-day horizon, the market may begin to discount the geopolitical risk premium if no physical supply disruptions materialize, allowing the underlying bearish fundamentals of projected oversupply to exert more downward pressure."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 63.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 56.0 },
#         { "quantile": 0.1, "value": 58.0 },
#         { "quantile": 0.2, "value": 59.5 },
#         { "quantile": 0.3, "value": 61.0 },
#         { "quantile": 0.4, "value": 62.0 },
#         { "quantile": 0.5, "value": 63.0 },
#         { "quantile": 0.6, "value": 64.0 },
#         { "quantile": 0.7, "value": 65.5 },
#         { "quantile": 0.8, "value": 67.5 },
#         { "quantile": 0.9, "value": 70.0 },
#         { "quantile": 0.95, "value": 72.0 }
#       ],
#       "rationale": "By the 21-day horizon, the structural oversupply narrative is expected to gain more weight, potentially pushing prices lower unless geopolitical tensions escalate significantly. The range reflects the high uncertainty inherent in the geopolitical risk premium."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Supply Surplus",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Geopolitical Risk Premium",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "Physical Market Tightness",
#       "category": "macro",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Oversupply Dominance",
#       "probability": 0.5,
#       "price_low": 55.0,
#       "price_high": 62.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply Surplus": "bearish",
#         "Geopolitical Risk Premium": "neutral",
#         "Physical Market Tightness": "bearish"
#       }
#     },
#     {
#       "name": "Geopolitical Escalation",
#       "probability": 0.3,
#       "price_low": 68.0,
#       "price_high": 78.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply Surplus": "neutral",
#         "Geopolitical Risk Premium": "bullish",
#         "Physical Market Tightness": "bullish"
#       }
#     },
#     {
#       "name": "Supply Shock Tail Case",
#       "probability": 0.2,
#       "price_low": 75.0,
#       "price_high": 90.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Supply Surplus": "bearish",
#         "Geopolitical Risk Premium": "bullish",
#         "Physical Market Tightness": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently caught between a bearish structural outlook (oversupply) and a bullish geopolitical risk premium. My forecast reflects a gradual drift toward the bearish fundamentals as the risk premium potentially fades, while acknowledging the significant upside risk if geopolitical tensions escalate into actual supply disruptions."
# }
# predict() failed at origin 2026-02-02 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...al supply disruptions.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 65.2,
#       "quantiles": [
#         {"quantile": 0.05, "value": 62.5},
#         {"quantile": 0.1, "value": 63.2},
#         {"quantile": 0.2, "value": 64.0},
#         {"quantile": 0.3, "value": 64.5},
#         {"quantile": 0.4, "value": 64.8},
#         {"quantile": 0.5, "value": 65.2},
#         {"quantile": 0.6, "value": 65.6},
#         {"quantile": 0.7, "value": 66.1},
#         {"quantile": 0.8, "value": 66.8},
#         {"quantile": 0.9, "value": 67.5},
#         {"quantile": 0.95, "value": 68.2}
#       ],
#       "rationale": "Short-term price action is dominated by the recent rally to $65.20, supported by geopolitical risk premiums. The 5-day horizon remains tight as the market digests the sustainability of this move against the backdrop of structural oversupply concerns."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 64.5,
#       "quantiles": [
#         {"quantile": 0.05, "value": 60.5},
#         {"quantile": 0.1, "value": 61.5},
#         {"quantile": 0.2, "value": 62.5},
#         {"quantile": 0.3, "value": 63.5},
#         {"quantile": 0.4, "value": 64.0},
#         {"quantile": 0.5, "value": 64.5},
#         {"quantile": 0.6, "value": 65.2},
#         {"quantile": 0.7, "value": 66.0},
#         {"quantile": 0.8, "value": 67.0},
#         {"quantile": 0.9, "value": 68.5},
#         {"quantile": 0.95, "value": 69.5}
#       ],
#       "rationale": "Over 10 days, the market is expected to begin pricing in the fundamental reality of the global supply surplus, potentially softening the recent geopolitical premium if no new escalations occur."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 63.0,
#       "quantiles": [
#         {"quantile": 0.05, "value": 57.0},
#         {"quantile": 0.1, "value": 58.5},
#         {"quantile": 0.2, "value": 60.0},
#         {"quantile": 0.3, "value": 61.5},
#         {"quantile": 0.4, "value": 62.2},
#         {"quantile": 0.5, "value": 63.0},
#         {"quantile": 0.6, "value": 64.0},
#         {"quantile": 0.7, "value": 65.5},
#         {"quantile": 0.8, "value": 67.5},
#         {"quantile": 0.9, "value": 69.5},
#         {"quantile": 0.95, "value": 71.0}
#       ],
#       "rationale": "By the 21-day horizon, the structural bearish pressure from the projected global supply surplus is expected to exert more influence, leading to a gradual drift lower from current levels, barring a major geopolitical shock."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Supply Surplus",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Geopolitical Risk Premium",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "Physical Market Tightness",
#       "category": "macro",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Fundamental Correction",
#       "probability": 0.5,
#       "price_low": 58.0,
#       "price_high": 64.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply Surplus": "bearish",
#         "Geopolitical Risk Premium": "neutral",
#         "Physical Market Tightness": "bearish"
#       }
#     },
#     {
#       "name": "Geopolitical Escalation",
#       "probability": 0.3,
#       "price_low": 66.0,
#       "price_high": 75.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Supply Surplus": "neutral",
#         "Geopolitical Risk Premium": "bullish",
#         "Physical Market Tightness": "bullish"
#       }
#     },
#     {
#       "name": "Supply Shock / Tail Event",
#       "probability": 0.2,
#       "price_low": 72.0,
#       "price_high": 85.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Supply Surplus": "bearish",
#         "Geopolitical Risk Premium": "bullish",
#         "Physical Market Tightness": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently caught between a short-term geopolitical floor and a medium-term structural surplus. My forecast reflects a gradual erosion of the current price as the market shifts focus toward the supply surplus, while maintaining wide ranges to account for the high sensitivity to geopolitical developments."
# }
# predict() failed at origin 2026-02-02 (attempt 2/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, point_forecast (63.00) at horizon 21 deviates from the probability-weighted scenario price (67.35) by 4.35, exceeding the 15%-of-spread tolerance (4.05). The model's point forecast is inconsistent with its own stated scenarios. [type=value_error, input_value={'forecasts': [{'horizon'...olitical developments.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 97.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 88.0 },
#         { "quantile": 0.1, "value": 90.5 },
#         { "quantile": 0.2, "value": 93.0 },
#         { "quantile": 0.3, "value": 95.0 },
#         { "quantile": 0.4, "value": 96.5 },
#         { "quantile": 0.5, "value": 97.5 },
#         { "quantile": 0.6, "value": 99.0 },
#         { "quantile": 0.7, "value": 101.0 },
#         { "quantile": 0.8, "value": 103.5 },
#         { "quantile": 0.9, "value": 107.0 },
#         { "quantile": 0.95, "value": 110.0 }
#       ],
#       "rationale": "Short-term price action remains dominated by the Strait of Hormuz closure. The market is pricing in a high-risk premium, but the volatility is extreme as traders weigh the physical supply shortfall against potential diplomatic breakthroughs or inventory releases."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 95.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 82.0 },
#         { "quantile": 0.1, "value": 85.0 },
#         { "quantile": 0.2, "value": 88.0 },
#         { "quantile": 0.3, "value": 91.0 },
#         { "quantile": 0.4, "value": 93.5 },
#         { "quantile": 0.5, "value": 95.0 },
#         { "quantile": 0.6, "value": 97.0 },
#         { "quantile": 0.7, "value": 100.0 },
#         { "quantile": 0.8, "value": 104.0 },
#         { "quantile": 0.9, "value": 109.0 },
#         { "quantile": 0.95, "value": 113.0 }
#       ],
#       "rationale": "Over the 10-day horizon, the market will likely begin to see the impact of demand destruction and potential strategic inventory releases. The uncertainty remains high, but the probability of a price correction increases as the market tests the sustainability of current levels."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 90.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 75.0 },
#         { "quantile": 0.1, "value": 78.0 },
#         { "quantile": 0.2, "value": 82.0 },
#         { "quantile": 0.3, "value": 85.0 },
#         { "quantile": 0.4, "value": 88.0 },
#         { "quantile": 0.5, "value": 90.0 },
#         { "quantile": 0.6, "value": 93.0 },
#         { "quantile": 0.7, "value": 97.0 },
#         { "quantile": 0.8, "value": 102.0 },
#         { "quantile": 0.9, "value": 108.0 },
#         { "quantile": 0.95, "value": 115.0 }
#       ],
#       "rationale": "By the 21-day horizon, the market expects either a resolution to the Strait of Hormuz crisis or a more permanent structural adjustment. The baseline assumes a gradual easing of the risk premium, though the tail-risk of escalation remains significant."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Strait of Hormuz Geopolitical Risk",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "Global Oil Demand Elasticity",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Strategic Petroleum Reserve (SPR) Intervention",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "high"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Diplomatic De-escalation",
#       "probability": 0.4,
#       "price_low": 75.0,
#       "price_high": 85.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Geopolitical Risk": "bearish",
#         "Global Oil Demand Elasticity": "neutral",
#         "Strategic Petroleum Reserve (SPR) Intervention": "bearish"
#       }
#     },
#     {
#       "name": "Prolonged Blockade & Escalation",
#       "probability": 0.4,
#       "price_low": 100.0,
#       "price_high": 120.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Geopolitical Risk": "bullish",
#         "Global Oil Demand Elasticity": "bullish",
#         "Strategic Petroleum Reserve (SPR) Intervention": "bullish"
#       }
#     },
#     {
#       "name": "Total Regional Conflict (Tail Case)",
#       "probability": 0.2,
#       "price_low": 120.0,
#       "price_high": 150.0,
#       "is_tail_case": true,
#       "stances": {
#         "Strait of Hormuz Geopolitical Risk": "bullish",
#         "Global Oil Demand Elasticity": "bullish",
#         "Strategic Petroleum Reserve (SPR) Intervention": "bullish"
#       }
#     }
#   ],
#   "rationale": "The WTI market is currently in a state of extreme volatility due to the closure of the Strait of Hormuz. The forecast reflects a high-risk premium that is expected to persist in the short term but potentially moderate as the market adjusts to the supply shock or as diplomatic efforts gain traction. The scenarios highlight the binary nature of the current geopolitical risk."
# }
# predict() failed at origin 2026-04-13 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, point_forecast (90.00) at horizon 21 deviates from the probability-weighted scenario price (103.00) by 13.00, exceeding the 15%-of-spread tolerance (11.25). The model's point forecast is inconsistent with its own stated scenarios. [type=value_error, input_value={'forecasts': [{'horizon'...ent geopolitical risk.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 96.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 88.0 },
#         { "quantile": 0.1, "value": 90.5 },
#         { "quantile": 0.2, "value": 92.5 },
#         { "quantile": 0.3, "value": 94.0 },
#         { "quantile": 0.4, "value": 95.5 },
#         { "quantile": 0.5, "value": 96.5 },
#         { "quantile": 0.6, "value": 98.0 },
#         { "quantile": 0.7, "value": 99.5 },
#         { "quantile": 0.8, "value": 101.5 },
#         { "quantile": 0.9, "value": 104.0 },
#         { "quantile": 0.95, "value": 106.0 }
#       ],
#       "rationale": "Short-term price action remains dominated by the Strait of Hormuz blockade. The market is in a holding pattern, awaiting news on diplomatic negotiations. The 5-day horizon reflects high sensitivity to headline risk."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 95.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 84.0 },
#         { "quantile": 0.1, "value": 87.0 },
#         { "quantile": 0.2, "value": 90.0 },
#         { "quantile": 0.3, "value": 92.0 },
#         { "quantile": 0.4, "value": 93.5 },
#         { "quantile": 0.5, "value": 95.0 },
#         { "quantile": 0.6, "value": 97.0 },
#         { "quantile": 0.7, "value": 99.0 },
#         { "quantile": 0.8, "value": 102.0 },
#         { "quantile": 0.9, "value": 105.0 },
#         { "quantile": 0.95, "value": 108.0 }
#       ],
#       "rationale": "Over 10 days, the market may begin to price in a higher probability of a diplomatic breakthrough or, conversely, a more entrenched, long-term supply disruption. The range widens to reflect this binary uncertainty."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 93.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 78.0 },
#         { "quantile": 0.1, "value": 82.0 },
#         { "quantile": 0.2, "value": 86.0 },
#         { "quantile": 0.3, "value": 89.0 },
#         { "quantile": 0.4, "value": 91.0 },
#         { "quantile": 0.5, "value": 93.0 },
#         { "quantile": 0.6, "value": 96.0 },
#         { "quantile": 0.7, "value": 100.0 },
#         { "quantile": 0.8, "value": 105.0 },
#         { "quantile": 0.9, "value": 110.0 },
#         { "quantile": 0.95, "value": 115.0 }
#       ],
#       "rationale": "By 21 days, the market will likely have reached a resolution or a new, more permanent state of crisis. The wider distribution reflects the potential for either a significant price correction upon peace or a sharp spike if the blockade is deemed permanent."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Strait of Hormuz Blockade",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "Global Demand Weakness",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Strategic Petroleum Reserve Releases",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Diplomatic Breakthrough",
#       "probability": 0.4,
#       "price_low": 75.0,
#       "price_high": 85.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Blockade": "bearish",
#         "Global Demand Weakness": "bearish",
#         "Strategic Petroleum Reserve Releases": "neutral"
#       }
#     },
#     {
#       "name": "Entrenched Impasse",
#       "probability": 0.45,
#       "price_low": 95.0,
#       "price_high": 105.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Blockade": "bullish",
#         "Global Demand Weakness": "neutral",
#         "Strategic Petroleum Reserve Releases": "bullish"
#       }
#     },
#     {
#       "name": "Escalation to Conflict",
#       "probability": 0.15,
#       "price_low": 110.0,
#       "price_high": 130.0,
#       "is_tail_case": true,
#       "stances": {
#         "Strait of Hormuz Blockade": "bullish",
#         "Global Demand Weakness": "neutral",
#         "Strategic Petroleum Reserve Releases": "bullish"
#       }
#     }
#   ],
#   "rationale": "The WTI market is currently defined by the binary outcome of the Strait of Hormuz crisis. Prices are elevated but constrained by weak global demand and the use of strategic reserves. The forecast reflects a cautious outlook, with a slight downward bias as the market anticipates a potential diplomatic resolution, while acknowledging the significant tail risk of further escalation."
# }
# predict() failed at origin 2026-05-25 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...of further escalation.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview) ✓
# 20:27:37 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:30:57 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:34:12 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:37:35 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:40:48 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:44:07 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:47:36 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:51:01 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 20:54:12 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#   CFM Agent v5.2 ✓
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#   CFM Agent v5.2.2 (ARIMA only) ✓
#
# 2026 evaluation complete.

# %%
# ── Save eval results for NB06 ───────────────────────────────────────────────
# Only baseline predictors are written so uncommenting optional predictors
# above does not add extra rows to the NB06 scorecard.
for _name, _result_dict in eval_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"eval_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in eval_results)} eval result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 eval result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 6. Scorecard
#
# Out-of-sample performance of every active predictor on the 2026 eval period.
# These numbers are the **stateless baseline** the adaptive agent variants must
# beat in Notebook 6 to demonstrate that training added value.

# %%
from energy_oil_forecasting.analysis import score_backtest_results


scorecard_rows = []
for name in PREDICTORS:
    if name not in eval_results:
        continue
    scores = score_backtest_results(eval_results[name], data_service)
    scorecard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS (2026)": scores.get("mean_crps", float("nan")),
            "MAE h=21d (2026)": scores.get("mae_h21", float("nan")),
            "80% CI Coverage": scores.get("coverage_80", float("nan")),
        }
    )

df_scorecard = pd.DataFrame(scorecard_rows).set_index("Predictor")
df_scorecard = df_scorecard.sort_values("Mean CRPS (2026)")

print("━" * 72)
print("2026 EVAL SCORECARD — STATELESS BASELINE:")
print("━" * 72)
print(df_scorecard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2026 EVAL SCORECARD — STATELESS BASELINE:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS (2026)  MAE h=21d (2026)  80% CI Coverage
# Predictor
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)          7.891830         10.617600             60.0
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                            8.145926         10.389600             52.0
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)                   8.332231         10.518862             56.0
# CFM Agent v5.2.2 (ARIMA only)                                                         8.517698         10.463792             56.0
# AutoARIMA                                                                             8.519640         10.498294             56.0
# CFM Agent v5.2                                                                        9.011747         10.609030             44.0
# Naive (Last Value)                                                                   10.489200         10.489200              0.0

# %% [markdown]
# ---
# ## 7. Diagnostics — reading past the leaderboard
#
# The scorecard above is a single number per method. That hides *where* the score
# comes from and *whether the ranking is even real*. The next cells decompose it
# straight from the eval predictions — so they recompute on any rerun, smoke or
# full:
#
# - **CRPS by horizon** — does a method win everywhere, or is its mean dominated by
#   one horizon? (For a short forecast, the 5-day calls are easy and nearly tied;
#   the ranking is usually decided by the longest horizon.)
# - **Mean CRPS ± standard error** — with only a handful of origins, are the gaps
#   between methods bigger than the noise, or is the "winner" a coin flip?
#
# With the **smoke spec (2 origins → a few scored points)** expect wide error bars
# and an unstable ranking. That is exactly why a surprising leaderboard here is not
# yet evidence of anything — it is a pipeline check.

# %%
from energy_oil_forecasting import viz
from energy_oil_forecasting.analysis import (
    build_price_frame,
    eval_narrative_md,
    extract_agent_rationales,
    leaderboard_with_uncertainty,
    per_horizon_crps,
    predictions_to_frame,
)
from IPython.display import HTML, Markdown, display  # noqa: A004


# Explode every scored 2026 eval prediction into one tidy row per
# (predictor, origin, horizon): point, 80% interval, realised price, and CRPS.
# Everything in Sections 7–10 reads from this frame, so it all recomputes when
# you flip SMOKE_TEST off and rerun.
price_df = build_price_frame(data_service)
eval_frame = predictions_to_frame(eval_results, data_service)
eval_board = leaderboard_with_uncertainty(eval_frame)
ph_crps = per_horizon_crps(eval_frame)

print("━" * 72)
print("MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):")
print("━" * 72)
print(ph_crps.round(2).to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                                h=5d  h=10d  h=21d    All
# predictor
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   5.97   5.51  11.67   7.89
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     6.72   6.49  10.86   8.15
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            7.88   5.63  10.89   8.33
# CFM Agent v5.2.2 (ARIMA only)                                                  8.28   5.68  10.97   8.52
# AutoARIMA                                                                      8.27   5.71  10.95   8.52
# CFM Agent v5.2                                                                 8.67   6.20  11.54   9.01
# Naive (Last Value)                                                            10.23   6.96  13.50  10.49

# %%
# Heatmap of the table above. Read it left-to-right: the short-horizon columns
# are usually a near-uniform green (everyone is right), and one long-horizon
# column carries the colour spread that sets the 'All' ranking.
viz.make_crps_heatmap(ph_crps)

# %%
# Same leaderboard, now with a standard-error bar on each mean. If the bars of
# the top methods overlap, their ordering is not statistically distinguishable —
# the honest verdict when only a few origins have been scored.
viz.make_leaderboard_interval_chart(eval_board)

# %% [markdown]
# ---
# ## 8. What are the top methods actually forecasting?
#
# A CRPS number doesn't show *behaviour*. Below, each leading method's **median
# forecast and 80% interval** are drawn against the realised WTI path at every
# eval origin. This is where the leaderboard becomes legible — watch for who
# tracks the move, who simply anchors to the last price, and whose intervals are
# too narrow to cover the outcome when the market jumps.

# %%
# Plot the leaderboard's top methods, and always include the best LLM/agent
# method for contrast (so the chart compares families even when a baseline leads).
_leaders = list(eval_board.index[:3])
_best_llm = next((p for p in eval_board.index if eval_board.loc[p, "family"] == "LLM / Agent"), None)
if _best_llm and _best_llm not in _leaders:
    _leaders.append(_best_llm)
print(f"Showing: {', '.join(_leaders)}")
viz.make_eval_forecast_chart(eval_frame, price_df, _leaders)
# Out:
# Showing: News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview), News Agent Scenario Schema (gemini-3.1-flash-lite-preview), News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)

# %% [markdown]
# ---
# ## 9. Reading the agent's reasoning
#
# The news-reading agent attaches a free-text **rationale** to every forecast, and
# a link to the full **Langfuse trace**. These are pulled straight from the
# prediction metadata. This is where a surprising score becomes interpretable: you
# can read whether the agent actually saw the geopolitical risk, and *how* it
# turned that into a price and an interval — including, often, an interval far too
# narrow for a regime shift.

# %%
# One card per (agent, origin): the rationale, the per-horizon note, and a link
# to the full reasoning trace. Empty only if no LLM/agent predictor is enabled.
eval_rationales = extract_agent_rationales(eval_results)
display(HTML(viz.render_rationales_html(eval_rationales)))
# Out:
# <div style='max-width:900px'><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-02 &nbsp; point $64.8 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/18f376203dad8b63b79f2debd783bf0f' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The market is currently reacting to short-term, weather-related supply disruptions that have buoyed prices above $65. However, underlying fundamental expectations for 2026 remain geared toward surplus. My forecasts anticipate a mean reversion as the temporary supply constraints normalize, balanced against potential volatility from ongoing geopolitical tensions.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term forecast reflects a potential cooling off from the rapid late-January rally driven by storm-related disruptions, as production normalizes.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-16 &nbsp; point $62.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/835629a5bfec2925b0d1d9ca34e64de5' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The market is currently caught in a tug-of-war between fundamental bearish pressures (rising US inventories and weakening global demand forecasts) and the persistent risk of supply-side disruption from geopolitical tensions in the Middle East. My forecast reflects a baseline expectation of fundamental drift downward, with significant upside variance contingent on geopolitical developments.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term horizon (5 days) expected to remain under pressure from recent bearish IEA reports and inventory data, offset slightly by existing geopolitical risk premia.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-03-02 &nbsp; point $68.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/c64a3c3ba89594462ce1ebbe5cfc2a2a' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The forecast is dominated by the conflict in the Middle East and its impact on the Strait of Hormuz. While fundamental supply/demand metrics suggest moderation, the physical risk premium is currently the primary driver of WTI price action. The scenarios represent a path of resolution, a continuation of the current crisis, and an extreme tail event of full supply disruption.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term momentum driven by the physical supply risk in the Middle East will likely keep prices elevated. Near-term volatility remains high as markets price in uncertainty regarding the Strait of Hormuz.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-03-16 &nbsp; point $95.0 &nbsp; <a href='https://us.cloud.langfuse.com/projec ...

# %% [markdown]
# ---
# ## 10. Takeaways — computed from this run
#
# The summary below is **generated from the eval results in memory, not
# hard-coded**, so it always matches what actually ran: the real winner, whether
# its lead clears the noise floor, the horizon that decided the ranking, the
# best-performing family, and a calibration line. Flip `SMOKE_TEST` off, rerun,
# and these takeaways update themselves with the full leaderboard.

# %%
display(Markdown(eval_narrative_md(eval_frame, smoke=SMOKE_TEST)))
# Out:
# 1. **News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)** has the best mean CRPS (7.89) on the 2026 evaluation, ahead of **News Agent Scenario Schema (gemini-3.1-flash-lite-preview)** (8.15) by 0.25 — **well within the combined standard error**, so the ranking here is not statistically distinguishable from noise.
# 2. The leaderboard is **decided at h=21d**, where CRPS ranges 0.3–34.4 across methods; at the short h=10d horizon the methods are nearly tied (range 0.2–26.5). A handful of long-horizon points drives the whole ranking.
# 3. **By family** (mean CRPS): LLM / Agent 8.35, Numerical ML 8.52, Baseline 10.49. Best family this window: **LLM / Agent**.
# 4. **Calibration:** News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)'s 80% interval covered 60% of outcomes (target 80%) over its 25 scored point(s). With this few, coverage this far from target is itself a small-sample artefact, not necessarily mis-calibration.
# 5. Based on 9 origins / 175 scored points.

# %% [markdown]
# ---
# ## 11. What stateless methods can't do
#
# Sections 7–10 score and dissect this run on its own terms. But every method here
# shares one structural limit, independent of who topped the leaderboard: it is
# calibrated (or prompted) **once and never updated between rounds**. That is
# intentional — it creates a clean baseline — but it leaves a systematic gap:
#
# - **No error feedback.** If a method's intervals are consistently too narrow in
#   an elevated-vol regime (read the coverage line in Section 10, and the squashed
#   error bars in Section 8), it keeps making the same mistake. Nothing updates its
#   calibration between origins.
#
# - **No strategy evolution.** Each prediction starts from the same prior — the
#   same fitted model, or the same prompt. Resolved outcomes disappear without
#   influencing future forecasts.
#
# - **Context without memory.** Even the news agent re-reads the world each origin;
#   it does not accumulate what worked. The rationales in Section 9 are written
#   fresh every time, with no record of how the last one resolved.
#
# → **Notebook 5** introduces adaptive agents that study the 2025 backtest, record
# systematic observations, and calibrate their strategies accordingly. At inference
# time, each agent receives the live stateless estimate and decides how to adjust
# it — applying what it learned from training.
#
# → **Notebook 6** evaluates whether any training approach actually improved
# out-of-sample performance on the held-out 2026 data — measured against the
# stateless baseline this notebook just established.

# %%
from aieng.forecasting.methods.agentic.agent_factory import ContextRetrievalConfig
print("verifier_model" in ContextRetrievalConfig.model_fields)
print(ContextRetrievalConfig.model_fields.keys())
# Out:
# True
# dict_keys(['enabled', 'search_model', 'instruction', 'enforce_cutoff', 'temperature', 'max_output_tokens', 'verifier_model', 'verifier_max_attempts', 'verifier_confidence_threshold'])

# %%
import glob, os, datetime
for path in glob.glob("**/data/predictions/**/*scenario_schema*", recursive=True):
    print(datetime.datetime.fromtimestamp(os.path.getmtime(path)), path)
# Out:
# 2026-08-20 06:54:33.409842 data/predictions/scenario_schema_enhanced_consistency_test
# 2026-07-25 16:59:50.483749 data/predictions/energy_oil_eval_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:06:56.632109 data/predictions/energy_oil_eval_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-07-25 16:48:08.773386 data/predictions/energy_oil_backtest_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 21:54:58.047101 data/predictions/consistency_test_run_2/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-19 21:54:36.130130 data/predictions/consistency_test_run_1/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-20 07:53:29.196866 data/predictions/scenario_schema_enhanced_consistency_test/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_forecast.yaml
# 2026-08-19 21:54:14.089158 data/predictions/consistency_test_run_0/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-19 15:00:36.464605 data/predictions/energy_oil_backtest_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 18:42:02.856250 data/predictions/energy_oil_backtest_10yr_quarterly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:26:18.033594 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-21 20:12:48.327794 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_anchored_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-20 11:48:11.227083 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-21 20:17:13.070002 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-21 20:24:35.195679 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_anchored_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-21 20:19:48.974535 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml

# %% [markdown]
# # WTI Crude Oil Price Forecasting — Stateless Methods: Systematic Backtest (Notebook 4 of 7)
#
# This notebook simulates a rigorous production forecasting workflow:
#
# 1. Run a **rolling weekly backtest across 2025** using
#    `energy_oil_backtest.yaml` for all candidate predictors.
# 2. Compute metrics — **CRPS** for 5/10/21-day trajectories.
# 3. Select the **top contender configurations** based solely on 2025
#    historical performance (no peeking at 2026).
# 4. Let the contenders compete in the **2026 Protected Arena**
#    (`energy_oil_eval.yaml`) across the geopolitical price shock and its
#    aftermath — measuring adaptive real-time responsiveness and calibration.
#    The eval window runs through the most recent origin whose 21-business-day
#    horizon still resolves against cached data (see `scripts/fetch_wti.py`).
#
# The line-up spans three families behind one `Predictor` interface: **baselines**
# (Naive, AutoARIMA), **numerical ML** (LightGBM ± a leak-safe covariate panel),
# and **LLM/agent** methods (LLM-process forecasters and a news-reading analyst
# agent) — the last run on *both* project models, `gemini-3.1-flash-lite-preview`
# and `gemini-3.5-flash`. Every predictor is one toggle line in the registry in
# Section 2. Agent configs come from `energy_oil_forecasting.analyst_agent`.

# %% [markdown]
# ---
# ## 1. Setup, Data Registration & Spec Loading

# %%
import warnings
from pathlib import Path

import energy_oil_forecasting
import pandas as pd
import yaml
from aieng.forecasting.evaluation import (
    MultiTargetBacktestSpec,
    cached_multi_backtest,
    describe_spec,
)
from aieng.forecasting.models import ADVANCED_MODEL, LITE_MODEL
from energy_oil_forecasting.data import (
    DEFAULT_WTI_COVARIATE_SERIES_IDS,
    build_wti_multivariate_service,
)

from energy_oil_forecasting.scenario_schema_anchored import (
    build_wti_news_scenario_schema_anchored_config,
    build_wti_scenario_schema_anchored_predictor,
)


warnings.filterwarnings("ignore")

# ── Mode ──────────────────────────────────────────────────────────────────────
# Set SMOKE_TEST = True to run a 2-origin, 1-sample version of the notebook
# for fast local development and end-to-end CI testing. The full specs run
# 51 backtest + 8 eval origins; smoke runs 2 + 2.
SMOKE_TEST = False 

# ── Models ────────────────────────────────────────────────────────────────────
# The project standardises on two Vector-proxy models. Every LLM and agent
# predictor below is run once per model so we can compare them head-to-head.
# (bare proxy names — no "gemini/" prefix)
MODELS = [LITE_MODEL, ADVANCED_MODEL]  # "gemini-3.1-flash-lite-preview", "gemini-3.5-flash"

# ── Derived settings (do not edit below) ─────────────────────────────────────
N_SAMPLES = 1 if SMOKE_TEST else 3  # trajectories per LLMP-Sampled call

# LightGBM hyperparameters (shared by the univariate and +covariate variants).
LAGS = 21  # one trading month of lagged target/covariate history
NUM_SAMPLES_LGBM = 100 if SMOKE_TEST else 200  # Monte-Carlo draws for quantiles
LGBM_KWARGS = {"num_threads": 1, "n_jobs": 1, "verbosity": -1}  # deterministic, quiet

# Data service: WTI target + a leak-safe covariate panel (all Yahoo Finance —
# Brent, natural gas, gasoline, gold, USD index, the USL/USO futures-curve
# contango proxy, and VIX). Non-covariate predictors simply ignore the extras,
# so one service feeds the whole leaderboard. Unavailable tickers are skipped
# with a warning, so this still runs offline / under partial connectivity.
data_service = build_wti_multivariate_service()
COVARIATES = [c for c in DEFAULT_WTI_COVARIATE_SERIES_IDS if c in set(data_service.series_ids)]

spec_dir = Path(energy_oil_forecasting.__file__).parent / "specs"
if SMOKE_TEST:
    backtest_file, eval_file = "energy_oil_smoke.yaml", "energy_oil_eval_smoke.yaml"
else:
    backtest_file, eval_file = "energy_oil_backtest.yaml", "energy_oil_eval.yaml"

with open(spec_dir / backtest_file) as f:
    backtest_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))
with open(spec_dir / eval_file) as f:
    eval_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))



# ── Reduce origin frequency + give this window its own cache namespace ─────
# spec_id now depends on SMOKE_TEST too, so toggling smoke/full never collides
# with (or silently reuses) the other mode's cached results.
_suffix = "_smoke" if SMOKE_TEST else ""

#backtest_spec.stride = 21  # ~monthly → ~12 origins instead of 51 (full mode)
backtest_spec.stride = 10  # ~biweekly → ~26 origins instead of 51 (full mode)
backtest_spec.spec_id = f"energy_oil_backtest_biweekly{_suffix}"

#eval_spec.stride = 21      # ~monthly → ~5 origins instead of 18 (full mode)
eval_spec.stride = 10      # ~biweekly → ~9 origins instead of 18 (full mode)
eval_spec.spec_id = f"energy_oil_eval_biweekly{_suffix}"





print(f"{'⚡ SMOKE MODE' if SMOKE_TEST else '📊 FULL MODE'} — MODELS={MODELS}  N_SAMPLES={N_SAMPLES}")
print(f"Covariates registered ({len(COVARIATES)}): {', '.join(COVARIATES) or '(none)'}")
print()
print("━" * 72)
print("LOADED SPECIFICATIONS:")
print("━" * 72)
print(describe_spec(backtest_spec, data_service))
print(describe_spec(eval_spec, data_service))
# Out:
# 📊 FULL MODE — MODELS=['gemini-3.1-flash-lite-preview', 'gemini-3.5-flash']  N_SAMPLES=3
# Covariates registered (7): brent_log_ret_1b_l1b, natgas_log_ret_1b_l1b, gasoline_log_ret_1b_l1b, gold_log_ret_1b_l1b, dollar_index_log_ret_1b_l1b, oil_curve_contango_l1b, vix_level_l1b
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# LOADED SPECIFICATIONS:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MultiTargetBacktestSpec (spec_id=energy_oil_backtest_biweekly)
#   description: Weekly rolling backtest in 2025 for daily WTI crude oil price forecasting. Evaluates trajectory forecasts (5, 10, 21 business days) with CRPS/MAE and binary up-shock forecasts (climb > $5 in 5 business days) with Brier Score. Used to select the top contender models.
#   start:       2025-01-06 00:00:00
#   end:         2025-12-22 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B
#
# MultiTargetBacktestSpec (spec_id=energy_oil_eval_biweekly)
#   description: Prospective/out-of-sample evaluation period in 2026 for daily WTI crude oil. Evaluates selected contender models on 18 weekly origins from the early 2026 geopolitical price shock through its aftermath, to measure adaptive real-time forecasting performance.
#   start:       2026-02-02 00:00:00
#   end:         2026-06-01 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B

# %% [markdown]
# ---
# ## 2. Candidate Predictors
#
# This experiment puts a full slate of methods on the same `Predictor` interface and
# the same rolling backtest, spanning three families:
#
# | Family | Predictors | Role |
# |---|---|---|
# | **Baselines** | `Naive (Last Value)`, `AutoARIMA` | Carry-forward floor + the classical statistical anchor |
# | **Numerical ML** | `LightGBM`, `LightGBM + cov` (+ optional `Prophet`) | Gradient-boosted quantile regression on lagged price (and a leak-safe covariate panel — Brent, gas, gasoline, gold, USD index, the futures-curve contango proxy, and VIX). LightGBM-with-covariates was the strongest method in the S&P 500 study. |
# | **LLM / Agent** | `LLMP-Sampled`, `LLMP-Grid`, `News Agent` — each on **both** project models | LLM-process forecasters and a news-reading analyst agent, run on `gemini-3.1-flash-lite-preview` *and* `gemini-3.5-flash` |
#
# The predictor cell below is a **registry**: every method is one line with an
# `enabled` flag. Flip a flag to add or drop a predictor — the rest of the
# notebook (backtest, scoring, eval, scorecard) iterates over whatever is active.
# The two baselines are flagged `baseline=True` and are the only results written to
# `adaptive_agent/curriculum/` for Notebooks 5–6, so toggling the others never
# disturbs the downstream training data.

# %%
from dataclasses import dataclass
from typing import Callable

from aieng.forecasting.methods import (
    LastValuePredictor,
    QuantileGridLLMPredictor,
    QuantileGridLLMPredictorConfig,
    SampledTrajectoryLLMPredictor,
    SampledTrajectoryLLMPredictorConfig,
)
from aieng.forecasting.methods.numerical.darts_arima import DartsAutoARIMAPredictor
from aieng.forecasting.methods.numerical.darts_regression import DartsLightGBMPredictor
from energy_oil_forecasting.analyst_agent import (
    build_wti_agent_predictor,
    build_wti_news_config,
    build_wti_news_contrarian_config,
    build_wti_news_factors_v2_config,
    build_wti_news_scenario_schema_config,
    build_wti_scenario_schema_predictor,
)
from energy_oil_forecasting.cfm_agent_v_5_2 import (
    build_cfm_agent_config,
    build_cfm_agent_predictor,
)
from energy_oil_forecasting.cfm_agent_v_5_2_2_delta_governed import (
    build_cfm_agent_config_delta_governed,
    build_cfm_agent_predictor_delta_governed,
)
from energy_oil_forecasting.prophet_baseline import ProphetPredictor


@dataclass
class PredictorEntry:
    """One row in the experiment. Flip ``enabled`` to switch a predictor on/off."""

    name: str
    factory: Callable[[], object]  # lazy — built only when enabled
    enabled: bool = True
    baseline: bool = False  # baselines are saved to curriculum/ for NB05–06


# LLM / agent factories — each takes a model so the same recipe runs on both.
# LLMP-Sampled optionally serializes the covariate panel into the prompt
# (labeled exogenous-series blocks); the others are target-only. A distinct
# variant_tag keeps the +cov run separate in the cache and on the leaderboard.
def _llmp_sampled(model, covariates=None):
    return SampledTrajectoryLLMPredictor(
        SampledTrajectoryLLMPredictorConfig(
            model=model,
            n_samples=N_SAMPLES,
            covariate_series_ids=covariates,
            variant_tag="cov" if covariates else None,
        )
    )


def _llmp_grid(model):
    return QuantileGridLLMPredictor(QuantileGridLLMPredictorConfig(model=model))


#def _news_agent(model):
#    return build_wti_agent_predictor(build_wti_news_config(model=model))


#def _news_agent_contrarian(model):
#    return build_wti_agent_predictor(build_wti_news_contrarian_config(model=model))


def _news_agent(model):
    return build_wti_agent_predictor(
        build_wti_news_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                              )
    )


def _news_agent_contrarian(model):
    return build_wti_agent_predictor(
        build_wti_news_contrarian_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )


def _news_agent_factors_v2(model):
    return build_wti_agent_predictor(
        build_wti_news_factors_v2_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )

def _news_agent_scenario_schema(model):
    return build_wti_scenario_schema_predictor(
        build_wti_news_scenario_schema_config(model=model)
    )


def _news_agent_scenario_schema_zero_temp(model: str):
    """News Scenario Schema with temperature=0 for consistency testing."""
    print("🔥 Creating NEWS AGENT with temperature=0.0")  # ← ADD THIS
    config = build_wti_news_scenario_schema_config(
        model=model, 
        temperature=0.0
    )
    return build_wti_scenario_schema_predictor(config)

def _news_agent_scenario_schema_enhanced(model):
    from energy_oil_forecasting.scenario_schema_enhanced import (
        build_wti_news_scenario_schema_enhanced_config,
        build_wti_scenario_schema_enhanced_predictor,
    )
    config = build_wti_news_scenario_schema_enhanced_config(model=model)
    return build_wti_scenario_schema_enhanced_predictor(config)


def _news_agent_scenario_schema_anchored(model):
    config = build_wti_news_scenario_schema_anchored_config(model=model)
    return build_wti_scenario_schema_anchored_predictor(config)

    
def _cfm_agent_v_5_2():
    config = build_cfm_agent_config()
    return build_cfm_agent_predictor(config)

def _cfm_agent_v_5_2_arima_only():
    from energy_oil_forecasting.cfm_agent_v_5_2 import (
        build_cfm_agent_config_arima_only,
        build_cfm_agent_predictor_arima_only,
    )
    config = build_cfm_agent_config_arima_only()
    return build_cfm_agent_predictor_arima_only(config)

def _cfm_agent_v_5_2_2_delta_governed():
    config = build_cfm_agent_config_delta_governed()
    return build_cfm_agent_predictor_delta_governed(config)



# ── Experiment registry ───────────────────────────────────────────────────────
# Toggle `enabled` on any line to include/exclude that predictor. LLM and agent
# methods are listed once per model so each can be switched on/off individually.
REGISTRY = [
    # Baselines — always saved to curriculum/ for the adaptive-agent notebooks.
    PredictorEntry("Naive (Last Value)", LastValuePredictor, enabled=True, baseline=True),
    PredictorEntry("AutoARIMA", DartsAutoARIMAPredictor, enabled=True, baseline=True),
    # Numerical ML — LightGBM was the strongest method in the S&P 500 study.
    PredictorEntry(
        "LightGBM",
        lambda: DartsLightGBMPredictor(lags=LAGS, num_samples=NUM_SAMPLES_LGBM, lgbm_kwargs=LGBM_KWARGS),
        enabled=False,
    ),
    PredictorEntry(
        "LightGBM + cov",
        lambda: DartsLightGBMPredictor(
            lags=LAGS,
            lags_past_covariates=LAGS,
            covariate_series_ids=COVARIATES,
            num_samples=NUM_SAMPLES_LGBM,
            lgbm_kwargs=LGBM_KWARGS,
        ),
        enabled=False,
    ),
    PredictorEntry("Prophet", ProphetPredictor, enabled=False),
    # LLM processes and the news agent — one row per model in MODELS.
    PredictorEntry(f"LLMP-Sampled ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Sampled ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL), enabled=False),
    # LLMP-Sampled with the covariate panel serialized into the prompt — the one
    # LLM method that can take covariates with no package change. Compare each of
    # these against its target-only twin above to see if context helps the LLM.
    PredictorEntry(f"LLMP-Sampled + cov ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL, COVARIATES), enabled=False),
    PredictorEntry(
        f"LLMP-Sampled + cov ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL, COVARIATES), enabled=False
    ),
    PredictorEntry(f"LLMP-Grid ({LITE_MODEL})", lambda: _llmp_grid(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Grid ({ADVANCED_MODEL})", lambda: _llmp_grid(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({LITE_MODEL})", lambda: _news_agent(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({ADVANCED_MODEL})", lambda: _news_agent(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent Contrarian ({LITE_MODEL})", lambda: _news_agent_contrarian(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Factors V2 ({LITE_MODEL})", lambda: _news_agent_factors_v2(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Scenario Schema ({LITE_MODEL})", lambda: _news_agent_scenario_schema(LITE_MODEL), enabled=True),
    PredictorEntry(f"News Agent Scenario Schema - zero temp ({LITE_MODEL})", 
                   lambda: _news_agent_scenario_schema_zero_temp(LITE_MODEL), 
                   enabled=False),
    PredictorEntry(f"News Agent Scenario Schema Enhanced - temp=0 ({LITE_MODEL})", 
                   lambda: _news_agent_scenario_schema_enhanced(LITE_MODEL), 
                    enabled=True),

    PredictorEntry(f"News Agent Scenario Schema Anchored ({LITE_MODEL})", 
               lambda: _news_agent_scenario_schema_anchored(LITE_MODEL), 
               enabled=True),

               
    PredictorEntry("CFM Agent v5.2", _cfm_agent_v_5_2, enabled=True),
    PredictorEntry("CFM Agent v5.2.2 (ARIMA only)", _cfm_agent_v_5_2_arima_only, enabled=True),
    PredictorEntry("CFM Agent v5.2.2 Delta-Governed", _cfm_agent_v_5_2_2_delta_governed, enabled=True),

    

]

# Instantiate only the enabled predictors (lazy factories skip the rest).
PREDICTORS = {e.name: e.factory() for e in REGISTRY if e.enabled}
_BASELINE_PREDICTORS = {e.name for e in REGISTRY if e.baseline}

print(f"Active predictors ({len(PREDICTORS)}):")
for name in PREDICTORS:
    tag = "  (baseline → curriculum/)" if name in _BASELINE_PREDICTORS else ""
    print(f"  {name}{tag}")
# Out:
# Active predictors (8):
#   Naive (Last Value)  (baseline → curriculum/)
#   AutoARIMA  (baseline → curriculum/)
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview)
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)
#   CFM Agent v5.2
#   CFM Agent v5.2.2 (ARIMA only)
#   CFM Agent v5.2.2 Delta-Governed

# %% [markdown]
# ---
# ## 3. Run the 2025 Historical Backtest
#
# All 51 weekly origins in 2025 are evaluated for each predictor.
# `cached_multi_backtest` caches results under `data/predictions/` so
# subsequent runs are instant.

# %%
import time

print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
print("LLM/agent runs are expensive — first run will take several minutes.\n")

backtest_results: dict[str, object] = {}
for i, (_name, _predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)  # pace between predictors, not just after a failure
    backtest_results[_name] = cached_multi_backtest(
        _predictor, backtest_spec, data_service,
        max_retries=4,     # was 2
        retry_delay=30.0,  # was 2.0 — long enough to clear an RPM window
        force_refresh=False, #(_name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {_name} ✓")

print("\nAll 2025 backtests complete.")

#print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
#print("LLM/agent runs are expensive — first run will take several minutes.\n")
#
#backtest_results: dict[str, object] = {}
#for _name, _predictor in PREDICTORS.items():
#    backtest_results[_name] = cached_multi_backtest(_predictor, backtest_spec, data_service)
#    print(f"  {_name} ✓")
#
#print("\nAll 2025 backtests complete.")
# Out:
# Running 2025 rolling backtest (8 predictor(s))...
# LLM/agent runs are expensive — first run will take several minutes.
#
#   Naive (Last Value) ✓
#   AutoARIMA ✓
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview) ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 62.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 58.5 },
#         { "quantile": 0.1, "value": 59.5 },
#         { "quantile": 0.2, "value": 60.5 },
#         { "quantile": 0.3, "value": 61.5 },
#         { "quantile": 0.4, "value": 62.0 },
#         { "quantile": 0.5, "value": 62.5 },
#         { "quantile": 0.6, "value": 63.5 },
#         { "quantile": 0.7, "value": 64.5 },
#         { "quantile": 0.8, "value": 65.5 },
#         { "quantile": 0.9, "value": 67.0 },
#         { "quantile": 0.95, "value": 68.5 }
#       ],
#       "rationale": "Short-term price action remains dominated by bearish sentiment from inventory builds and demand growth downgrades. The market is testing support levels near $60, with volatility expected to remain elevated as traders digest the IEA's demand outlook."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 61.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 56.0 },
#         { "quantile": 0.1, "value": 57.5 },
#         { "quantile": 0.2, "value": 59.0 },
#         { "quantile": 0.3, "value": 60.0 },
#         { "quantile": 0.4, "value": 60.8 },
#         { "quantile": 0.5, "value": 61.5 },
#         { "quantile": 0.6, "value": 62.5 },
#         { "quantile": 0.7, "value": 64.0 },
#         { "quantile": 0.8, "value": 66.0 },
#         { "quantile": 0.9, "value": 68.5 },
#         { "quantile": 0.95, "value": 70.5 }
#       ],
#       "rationale": "Over the 10-day horizon, the market will likely continue to price in the risk of OPEC+ production increases. The downside risk is significant if inventory data continues to show builds, though geopolitical risk provides a floor."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 60.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 53.0 },
#         { "quantile": 0.1, "value": 55.0 },
#         { "quantile": 0.2, "value": 57.0 },
#         { "quantile": 0.3, "value": 58.5 },
#         { "quantile": 0.4, "value": 59.5 },
#         { "quantile": 0.5, "value": 60.5 },
#         { "quantile": 0.6, "value": 62.0 },
#         { "quantile": 0.7, "value": 64.5 },
#         { "quantile": 0.8, "value": 67.5 },
#         { "quantile": 0.9, "value": 71.0 },
#         { "quantile": 0.95, "value": 74.0 }
#       ],
#       "rationale": "By the 21-day horizon, the market will have more clarity on the May OPEC+ production decisions. The structural concern regarding global demand growth, exacerbated by trade tensions, suggests a bias toward the lower end of the recent range."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Global Demand Growth",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "OPEC+ Supply Policy",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "US-China Trade Tensions",
#       "category": "macro",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "US Inventory Levels",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Bearish Demand/OPEC Overhang",
#       "probability": 0.5,
#       "price_low": 55.0,
#       "price_high": 62.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Demand Growth": "bearish",
#         "OPEC+ Supply Policy": "bearish",
#         "US-China Trade Tensions": "bearish",
#         "US Inventory Levels": "bearish"
#       }
#     },
#     {
#       "name": "Geopolitical Risk Premium",
#       "probability": 0.3,
#       "price_low": 63.0,
#       "price_high": 72.0,
#       "is_tail_case": false,
#       "stances": {
#         "Global Demand Growth": "neutral",
#         "OPEC+ Supply Policy": "bullish",
#         "US-China Trade Tensions": "neutral",
#         "US Inventory Levels": "neutral"
#       }
#     },
#     {
#       "name": "Supply Shock/Conflict Escalation",
#       "probability": 0.2,
#       "price_low": 68.0,
#       "price_high": 80.0,
#       "is_tail_case": true,
#       "stances": {
#         "Global Demand Growth": "neutral",
#         "OPEC+ Supply Policy": "bullish",
#         "US-China Trade Tensions": "neutral",
#         "US Inventory Levels": "bullish"
#       }
#     }
#   ],
#   "rationale": "The WTI market is currently in a bearish phase driven by demand concerns and inventory builds. My forecast reflects a cautious outlook, with the central scenario leaning toward continued pressure from macro headwinds and potential OPEC+ supply increases. The tail case accounts for a sudden geopolitical disruption that could rapidly reverse the current bearish sentiment."
# }
# predict() failed at origin 2025-04-28 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, point_forecast (60.50) at horizon 21 deviates from the probability-weighted scenario price (64.30) by 3.80, exceeding the 15%-of-spread tolerance (3.75). The model's point forecast is inconsistent with its own stated scenarios. [type=value_error, input_value={'forecasts': [{'horizon'...ent bearish sentiment.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 63.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 59.5 },
#         { "quantile": 0.1, "value": 60.5 },
#         { "quantile": 0.2, "value": 61.5 },
#         { "quantile": 0.3, "value": 62.5 },
#         { "quantile": 0.4, "value": 63.0 },
#         { "quantile": 0.5, "value": 63.5 },
#         { "quantile": 0.6, "value": 64.0 },
#         { "quantile": 0.7, "value": 64.5 },
#         { "quantile": 0.8, "value": 65.5 },
#         { "quantile": 0.9, "value": 66.5 },
#         { "quantile": 0.95, "value": 67.5 }
#       ],
#       "rationale": "Short-term price action is dominated by the market's absorption of the OPEC+ production increase. The point forecast reflects a slight downward drift from the $64.01 close as the market tests lower support levels."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 62.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 57.0 },
#         { "quantile": 0.1, "value": 58.5 },
#         { "quantile": 0.2, "value": 60.0 },
#         { "quantile": 0.3, "value": 61.0 },
#         { "quantile": 0.4, "value": 61.8 },
#         { "quantile": 0.5, "value": 62.5 },
#         { "quantile": 0.6, "value": 63.2 },
#         { "quantile": 0.7, "value": 64.0 },
#         { "quantile": 0.8, "value": 65.0 },
#         { "quantile": 0.9, "value": 66.5 },
#         { "quantile": 0.95, "value": 68.0 }
#       ],
#       "rationale": "Over the 10-day horizon, the market is expected to price in the reality of the increased supply. The distribution widens to reflect uncertainty regarding the speed of inventory builds."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 61.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 54.0 },
#         { "quantile": 0.1, "value": 56.0 },
#         { "quantile": 0.2, "value": 58.0 },
#         { "quantile": 0.3, "value": 59.5 },
#         { "quantile": 0.4, "value": 60.2 },
#         { "quantile": 0.5, "value": 61.0 },
#         { "quantile": 0.6, "value": 62.0 },
#         { "quantile": 0.7, "value": 63.5 },
#         { "quantile": 0.8, "value": 65.0 },
#         { "quantile": 0.9, "value": 67.0 },
#         { "quantile": 0.95, "value": 69.0 }
#       ],
#       "rationale": "By the 21-day horizon, the full impact of the OPEC+ policy shift is likely to be reflected in the price, with the market potentially testing the 52-week low if demand data remains weak."
#     }
#   ],
#   "factors": [
#     {
#       "name": "OPEC+ Supply Policy",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "Global Demand Growth",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Geopolitical Risk Premium",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "Inventory Build Expectations",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "high"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Oversupply Realization",
#       "probability": 0.6,
#       "price_low": 58.0,
#       "price_high": 63.0,
#       "is_tail_case": false,
#       "stances": {
#         "OPEC+ Supply Policy": "bearish",
#         "Global Demand Growth": "bearish",
#         "Geopolitical Risk Premium": "neutral",
#         "Inventory Build Expectations": "bearish"
#       }
#     },
#     {
#       "name": "Geopolitical Escalation",
#       "probability": 0.25,
#       "price_low": 65.0,
#       "price_high": 72.0,
#       "is_tail_case": false,
#       "stances": {
#         "OPEC+ Supply Policy": "neutral",
#         "Global Demand Growth": "neutral",
#         "Geopolitical Risk Premium": "bullish",
#         "Inventory Build Expectations": "neutral"
#       }
#     },
#     {
#       "name": "Demand Resilience/Soft Landing",
#       "probability": 0.15,
#       "price_low": 68.0,
#       "price_high": 75.0,
#       "is_tail_case": true,
#       "stances": {
#         "OPEC+ Supply Policy": "neutral",
#         "Global Demand Growth": "bullish",
#         "Geopolitical Risk Premium": "neutral",
#         "Inventory Build Expectations": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently in a bearish phase driven by the anticipated increase in OPEC+ supply and tepid global demand. The forecast reflects a downward bias, with the primary risk being a faster-than-expected inventory build. Geopolitical risks provide a floor, but are currently secondary to fundamental supply/demand imbalances."
# }
# predict() failed at origin 2025-09-01 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, point_forecast (61.00) at horizon 21 deviates from the probability-weighted scenario price (64.15) by 3.15, exceeding the 15%-of-spread tolerance (2.55). The model's point forecast is inconsistent with its own stated scenarios. [type=value_error, input_value={'forecasts': [{'horizon'...ply/demand imbalances.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview) ✓
# 19:10:17 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:13:15 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:15:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:18:44 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:21:37 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:24:22 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:27:08 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:29:54 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:32:45 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:35:37 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:38:25 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:41:12 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:43:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:46:46 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:49:37 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:52:24 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:55:14 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 19:58:08 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:00:57 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:03:47 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d0a82240>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d0517a40>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d6040>, 26639.775551059)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d05177a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d07cc1a0>, 26644.059231394)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d0734e30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d07d3620>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d7e00>, 26651.681056704)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d07d31a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d042b290>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d7850>, 26655.8453257)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d042ae10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d042a480>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c0130>, 26662.084721184)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d042a2a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d044b350>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c0830>, 26666.035553435)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d044a8d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d044b7d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1080>, 26672.389443765)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d044b500>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d044bdd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1fd0>, 26683.918042048)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046f8f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d04aec30>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1940>, 26687.94973165)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d04ae5a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d04ad340>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c29e0>, 26694.042404118)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d04ac3b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb2cb60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1be0>, 26698.565285496)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb2c140>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d0448a10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c33f0>, 26704.769227447)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d0448620>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb2d2b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c3540>, 26715.323446163)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb2f1d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046ef60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c3770>, 26720.302389654)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046ff80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfbc7680>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe0830>, 26726.146066123)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfbc7ce0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb9d310>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe0210>, 26730.757689949)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb9c110>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfbc4bc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe08a0>, 26767.304401168)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfbc6db0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfbc7a70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe0670>, 26772.174063785)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfbc6780>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d04ad160>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe0d00>, 26779.075059795)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfbc6480>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d04afbf0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1860>, 26783.346042139)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d04afcb0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb72e70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1e80>, 26789.634340731)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb738f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb959a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe2970>, 26800.489744312)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb71d00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfafe240>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe2b30>, 26804.878151551)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfaff950>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046fec0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046d3a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb70500>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c0590>, 26676.726073822)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046d100>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c2740>, 26709.454848341)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046ccb0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1be0>, 26793.904237545)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb73cb0>
# 20:06:42 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:09:33 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:12:20 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:15:12 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:18:03 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 20:20:58 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfaffc50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe3310>, 26811.214956563)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb96a20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa868d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe3460>, 26815.323667911)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfafed20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfafd220>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe3b60>, 26822.313853031)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfaffa40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa92360>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa300c0>, 26832.775779069)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa84d70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfafd580>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa30520>, 26836.859844253)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfafc9e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa91700>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa30910>, 26843.084816402)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa87d40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfac7d10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa30fa0>, 26847.427274281)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfac5a30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa900e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa31940>, 26853.229402915)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfac7620>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfac7ec0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa32660>, 26863.670888788)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa61d90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa09c10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa32820>, 26867.88996697)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa086e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa093d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa32510>, 26905.055558291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa867e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa40d10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa33380>, 26915.455918269)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa847d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa0b140>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa33620>, 26920.107365649)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa63740>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa429f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a4280>, 26926.502219056)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa08f20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf96f230>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa33310>, 26930.867309277)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf96ea50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf96eff0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a4910>, 26936.741845447)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa40ce0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf938c50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a4f30>, 26947.691306961)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa410a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf93aed0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a50f0>, 26952.111051201)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf939370>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9dea80>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a51d0>, 26958.531206361)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf9dd670>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf93b560>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a5940>, 26963.49837374)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf93be00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9dc530>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a5da0>, 26969.986420724)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf938dd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf990860>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a6820>, 26981.28630967)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf9df3e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf8f9640>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a69e0>, 26985.493835364)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf990890>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9dd880>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a46e0>, 26992.098725747)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf993380>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9dd190>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a7230>, 26996.627404755)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf8f8890>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfaff890>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa62bd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa414c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf93a390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf990590>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe34d0>, 26826.432515054)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfafdeb0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa31710>, 26857.450847143)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa62c90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa330e0>, 26909.387132227)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa40bf0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa32350>, 26941.141241027)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf93a030>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a5860>, 26974.237599322)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf9dff80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf93a1e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf757a80>, 27187.489183441)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf93a960>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf768500>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf680750>, 27180.497495118)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf7680b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf7733b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf682040>, 27351.072514488)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf772db0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc979760>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf682430>, 27343.276612532)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc9791f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc8f6480>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf681be0>, 27516.337902168)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc8f41d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc8f7650>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf683b60>, 27507.58446709)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf769550>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc95a960>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96c3d0>, 27688.695744335)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc99ae40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc90fad0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96d010>, 27682.623527348)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc90f770>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc982de0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96c440>, 27854.588269439)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc8f69c0>
#   CFM Agent v5.2 ✓
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e25d0ec0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96dbe0>, 27847.639174254)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e25d1400>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc95bdd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96c9f0>, 28019.505360173)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc95a720>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf768800>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96e6d0>, 28010.505957035)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf791820>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf7c4380>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96f460>, 28185.083350062)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf887380>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc9711f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f4750>, 28178.403830218)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc9733e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf752960>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f5080>, 28357.283479479)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf750e30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2615b50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f5240>, 28349.238854961)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2616ea0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2641640>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f58d0>, 28528.155286347)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2640bc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2769c70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7000>, 28519.603266177)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e276b5f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2642a20>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7850>, 28695.016912945)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2641340>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e26fe750>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7e70>, 28688.760912567)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e26ffe00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e260bb90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96d0f0>, 28861.560347902)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2609700>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf7901d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf681a90>, 28853.551380402)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf790ce0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf792390>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f6350>, 29029.797196214)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc998fe0>
#   CFM Agent v5.2.2 (ARIMA only) ✓
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e26b8b90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf600bb0>, 29021.110169897)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e26bb9e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc9aff50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf6016a0>, 29197.472660097)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf94c740>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e276f890>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf602580>, 29189.634801987)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e276f5c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2331ca0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf601da0>, 29368.999790479)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2331940>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2367740>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf601a20>, 29358.371955464)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e23676b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2364170>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf602c80>, 29533.254537126)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e23657c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e23659d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238c2f0>, 29528.009596251)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2365ca0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e23322d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96da90>, 29704.12082718)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2331250>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e276b0e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf6008a0>, 29695.687589565)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc999700>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf7c67e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238c130>, 29877.88723009)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf94dfd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e23323c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238c360>, 29868.143331452)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2331340>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e23718e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238db00>, 30046.928136902)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2370350>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc91bb60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238ee40>, 30038.605234639)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e24b8ef0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e24434d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238c280>, 30216.19634417)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2440350>
#   CFM Agent v5.2.2 Delta-Governed ✓
#
# All 2025 backtests complete.

# %% [markdown]
# ---
# ## 4. Performance Characterisation
#
# We score every active predictor on the 2025 backtest data:
# - **CRPS** (Continuous Ranked Probability Score) — sharpness + calibration combined
# - **MAE at h=21d** — point forecast accuracy at the longest horizon
#
# The leaderboard ranks the families against each other — how much structure the
# numerical methods (AutoARIMA, LightGBM ± covariates) extract over the naive
# floor, whether the covariate panel earns its keep, and how the LLM/agent methods
# compare across the two models. Where each method wins and where it struggles in
# 2025 is exactly the material the adaptive agent learns from in Notebook 5.

# %%
import math

from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []
for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    leaderboard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS": scores.get("mean_crps", float("nan")),
            "MAE h=21d": scores.get("mae_h21", float("nan")),
        }
    )

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print("2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:")
print("━" * 72)
print(df_leaderboard.to_string())

arima_crps = df_leaderboard.loc["AutoARIMA", "Mean CRPS"] if "AutoARIMA" in df_leaderboard.index else float("nan")
naive_crps = (
    df_leaderboard.loc["Naive (Last Value)", "Mean CRPS"]
    if "Naive (Last Value)" in df_leaderboard.index
    else float("nan")
)
if not math.isnan(arima_crps):
    print(
        f"\nAutoARIMA CRPS improvement over Naive: {naive_crps - arima_crps:.4f} ({(naive_crps - arima_crps) / naive_crps:.1%})"
    )
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     2.023526   2.750811
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   2.032458   2.762162
# CFM Agent v5.2                                                                 2.114478   2.856128
# AutoARIMA                                                                      2.504927   3.007586
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            2.553439   3.061890
# CFM Agent v5.2.2 (ARIMA only)                                                  2.569061   3.039546
# CFM Agent v5.2.2 Delta-Governed                                                2.578321   3.243257
# Naive (Last Value)                                                             3.002162   3.002162
#
# AutoARIMA CRPS improvement over Naive: 0.4972 (16.6%)

# %%
import math
import numpy as np
import pandas as pd
from datetime import datetime
from aieng.forecasting.evaluation.prediction import ContinuousForecast
from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []

for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    
    # Per-horizon MAE breakdown (instead of blended mae_h21)
    horizon_errors: dict[int, list[float]] = {h: [] for h in backtest_spec.tasks[0].horizons}
    for result in results.values():
        task = result.spec.task
        offset = pd.tseries.frequencies.to_offset(task.frequency)
        actual_df = data_service.get_series(task.target_series_id, as_of=datetime.now())
        actual_by_date = {
            pd.Timestamp(row["timestamp"]).normalize(): float(row["value"]) for _, row in actual_df.iterrows()
        }
        for pred in result.predictions:
            if not isinstance(pred.payload, ContinuousForecast):
                continue
            fd = pd.Timestamp(pred.forecast_date).normalize()
            actual = actual_by_date.get(fd)
            if actual is None:
                continue
            as_of = pd.Timestamp(pred.as_of)
            for h in task.horizons:
                if (as_of + offset * h).normalize() == fd:
                    horizon_errors[h].append(abs(pred.payload.point_forecast - actual))
                    break

    row = {
        "Predictor": name,
        "Mean CRPS": scores.get("mean_crps", float("nan")),
        "80% CI Coverage": scores.get("coverage_80", float("nan")),
    }
    for h in backtest_spec.tasks[0].horizons:
        errs = horizon_errors[h]
        row[f"MAE h={h}d"] = float(np.mean(errs)) if errs else float("nan")
    leaderboard_rows.append(row)

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print(f"2025 BACKTEST — PERFORMANCE BY HORIZON:")
print("━" * 72)
print(df_leaderboard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 BACKTEST — PERFORMANCE BY HORIZON:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS  80% CI Coverage  MAE h=5d  MAE h=10d  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     2.023526        70.270270  2.603462   2.508636   3.103077
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   2.032458        70.270270  2.684231   2.689545   2.901538
# CFM Agent v5.2                                                                 2.114478        86.486486  2.691111   2.641424   3.202817
# AutoARIMA                                                                      2.504927        91.891892  2.829270   2.800086   3.361480
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            2.553439        93.243243  2.790704   2.958416   3.420631
# CFM Agent v5.2.2 (ARIMA only)                                                  2.569061        91.891892  2.830347   2.907920   3.360122
# CFM Agent v5.2.2 Delta-Governed                                                2.578321        89.189189  2.864806   3.037463   3.795842
# Naive (Last Value)                                                             3.002162         0.000000  2.750770   2.741364   3.474231

# %%
# ── Save backtest results for NB05 / NB06 ────────────────────────────────────
# Only the baseline predictors (flagged in the registry above) are written to
# curriculum/ so that toggling the other predictors on/off does not change the
# files NB05 and NB06 depend on.
_CURRICULUM_DIR = Path("adaptive_agent/curriculum")
_CURRICULUM_DIR.mkdir(exist_ok=True)
for _name, _result_dict in backtest_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"backtest_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in backtest_results)} backtest result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 backtest result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 5. 2026 Evaluation — Held-Out Test Period
#
# We run every active predictor on **18 weekly origins spanning Feb–Jun 2026**
# (`energy_oil_eval.yaml`) — the major geopolitical volatility spike not seen
# during the 2025 backtest, plus its aftermath. The window runs through the
# most recent origin that still fully resolves against cached WTI data (the
# 21-business-day horizon needs data 21 business days past the origin).
#
# This evaluation serves two purposes:
# 1. **Measure out-of-sample robustness** — do the 2025 edges (statistical,
#    covariate, or LLM/agent) hold under a structural regime shift?
# 2. **Establish the stateless baseline** that the trained adaptive agents in
#    Notebook 6 are compared against. The baseline predictors' results are saved
#    to `adaptive_agent/curriculum/` for Notebooks 5 and 6 to load.

# %%
import time

print("Running 2026 evaluation...")
eval_results: dict[str, object] = {}
for i, (name, predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)
    eval_results[name] = cached_multi_backtest(
        predictor, eval_spec, data_service,
        max_retries=4,
        retry_delay=30.0,
        force_refresh=False, #(name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {name} ✓")

print("\n2026 evaluation complete.")

#print("Running 2026 evaluation...")
#eval_results: dict[str, object] = {}
#for name, predictor in PREDICTORS.items():
#    eval_results[name] = cached_multi_backtest(predictor, eval_spec, data_service)
#    print(f"  {name} ✓")

#print("\n2026 evaluation complete.")
# Out:
# Running 2026 evaluation...
#   Naive (Last Value) ✓
#   AutoARIMA ✓
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
#   News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview) ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 115.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 105.0 },
#         { "quantile": 0.1, "value": 108.0 },
#         { "quantile": 0.2, "value": 110.0 },
#         { "quantile": 0.3, "value": 112.0 },
#         { "quantile": 0.4, "value": 114.0 },
#         { "quantile": 0.5, "value": 115.0 },
#         { "quantile": 0.6, "value": 117.0 },
#         { "quantile": 0.7, "value": 120.0 },
#         { "quantile": 0.8, "value": 125.0 },
#         { "quantile": 0.9, "value": 130.0 },
#         { "quantile": 0.95, "value": 135.0 }
#       ],
#       "rationale": "The market is in a state of extreme volatility following the closure of the Strait of Hormuz. Prices have spiked significantly above the statistical baseline (ARIMA anchor) due to the immediate supply shock. The forecast reflects a high-risk environment where prices are expected to remain elevated until the situation stabilizes or military intervention occurs."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 110.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 95.0 },
#         { "quantile": 0.1, "value": 100.0 },
#         { "quantile": 0.2, "value": 103.0 },
#         { "quantile": 0.3, "value": 106.0 },
#         { "quantile": 0.4, "value": 108.0 },
#         { "quantile": 0.5, "value": 110.0 },
#         { "quantile": 0.6, "value": 113.0 },
#         { "quantile": 0.7, "value": 116.0 },
#         { "quantile": 0.8, "value": 120.0 },
#         { "quantile": 0.9, "value": 125.0 },
#         { "quantile": 0.95, "value": 130.0 }
#       ],
#       "rationale": "As the initial shock persists, the market begins to price in potential diplomatic or military responses. While the supply disruption remains, the extreme panic of the first few days may moderate slightly, leading to a modest cooling from the immediate post-closure peak."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 100.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 80.0 },
#         { "quantile": 0.1, "value": 85.0 },
#         { "quantile": 0.2, "value": 90.0 },
#         { "quantile": 0.3, "value": 94.0 },
#         { "quantile": 0.4, "value": 97.0 },
#         { "quantile": 0.5, "value": 100.0 },
#         { "quantile": 0.6, "value": 105.0 },
#         { "quantile": 0.7, "value": 110.0 },
#         { "quantile": 0.8, "value": 115.0 },
#         { "quantile": 0.9, "value": 120.0 },
#         { "quantile": 0.95, "value": 125.0 }
#       ],
#       "rationale": "By the 21-day horizon, the market expects either a resolution to the Strait of Hormuz closure or a clearer path regarding international intervention. The uncertainty remains high, but the extreme price levels are expected to face downward pressure as alternative supply routes are explored or strategic reserves are released."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Geopolitical Risk (Strait of Hormuz)",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "Global Supply-Demand Balance",
#       "category": "macro",
#       "tier": "core"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Prolonged Blockade",
#       "probability": 0.5,
#       "price_low": 100.0,
#       "price_high": 140.0,
#       "is_tail_case": false,
#       "stances": {
#         "Geopolitical Risk (Strait of Hormuz)": "bullish",
#         "Global Supply-Demand Balance": "bullish"
#       }
#     },
#     {
#       "name": "Diplomatic Resolution/Intervention",
#       "probability": 0.4,
#       "price_low": 75.0,
#       "price_high": 105.0,
#       "is_tail_case": false,
#       "stances": {
#         "Geopolitical Risk (Strait of Hormuz)": "bearish",
#         "Global Supply-Demand Balance": "neutral"
#       }
#     },
#     {
#       "name": "Full-Scale Regional Conflict",
#       "probability": 0.1,
#       "price_low": 130.0,
#       "price_high": 180.0,
#       "is_tail_case": true,
#       "stances": {
#         "Geopolitical Risk (Strait of Hormuz)": "bullish",
#         "Global Supply-Demand Balance": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently dominated by the sudden closure of the Strait of Hormuz. The forecast assumes a significant geopolitical risk premium will persist in the short term, with the price trajectory heavily dependent on the duration of the blockade and the potential for international intervention."
# }
# predict() failed at origin 2026-03-02 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...national intervention.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 102.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 94.0 },
#         { "quantile": 0.1, "value": 96.5 },
#         { "quantile": 0.2, "value": 98.5 },
#         { "quantile": 0.3, "value": 100.0 },
#         { "quantile": 0.4, "value": 101.5 },
#         { "quantile": 0.5, "value": 102.5 },
#         { "quantile": 0.6, "value": 103.5 },
#         { "quantile": 0.7, "value": 105.0 },
#         { "quantile": 0.8, "value": 107.0 },
#         { "quantile": 0.9, "value": 110.0 },
#         { "quantile": 0.95, "value": 115.0 }
#       ],
#       "rationale": "Short-term volatility remains extreme due to the Strait of Hormuz closure. The market is pricing in a significant risk premium, and while SPR releases are expected, the immediate supply shock dominates."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 105.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 92.0 },
#         { "quantile": 0.1, "value": 95.0 },
#         { "quantile": 0.2, "value": 98.0 },
#         { "quantile": 0.3, "value": 101.0 },
#         { "quantile": 0.4, "value": 103.0 },
#         { "quantile": 0.5, "value": 105.0 },
#         { "quantile": 0.6, "value": 107.0 },
#         { "quantile": 0.7, "value": 110.0 },
#         { "quantile": 0.8, "value": 114.0 },
#         { "quantile": 0.9, "value": 118.0 },
#         { "quantile": 0.95, "value": 125.0 }
#       ],
#       "rationale": "As the disruption persists, the market will likely test higher levels if no diplomatic resolution or alternative supply routes are established. Uncertainty widens significantly."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 98.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 80.0 },
#         { "quantile": 0.1, "value": 85.0 },
#         { "quantile": 0.2, "value": 90.0 },
#         { "quantile": 0.3, "value": 93.0 },
#         { "quantile": 0.4, "value": 96.0 },
#         { "quantile": 0.5, "value": 98.0 },
#         { "quantile": 0.6, "value": 101.0 },
#         { "quantile": 0.7, "value": 105.0 },
#         { "quantile": 0.8, "value": 110.0 },
#         { "quantile": 0.9, "value": 118.0 },
#         { "quantile": 0.95, "value": 128.0 }
#       ],
#       "rationale": "By the 21-day horizon, the market will likely have factored in the impact of coordinated SPR releases and potential demand destruction, leading to a potential mean reversion or stabilization, though the tail risk of a prolonged conflict remains high."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Strait of Hormuz Closure",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "SPR Intervention",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "medium"
#     },
#     {
#       "name": "Global Energy Security",
#       "category": "geopolitical",
#       "tier": "core"
#     },
#     {
#       "name": "US Domestic Production",
#       "category": "macro",
#       "tier": "core"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Prolonged Conflict",
#       "probability": 0.5,
#       "price_low": 100.0,
#       "price_high": 130.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Closure": "bullish",
#         "SPR Intervention": "neutral",
#         "Global Energy Security": "bullish",
#         "US Domestic Production": "neutral"
#       }
#     },
#     {
#       "name": "Diplomatic De-escalation",
#       "probability": 0.3,
#       "price_low": 80.0,
#       "price_high": 95.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Closure": "bearish",
#         "SPR Intervention": "bearish",
#         "Global Energy Security": "neutral",
#         "US Domestic Production": "neutral"
#       }
#     },
#     {
#       "name": "Total Supply Collapse (Tail Case)",
#       "probability": 0.2,
#       "price_low": 120.0,
#       "price_high": 160.0,
#       "is_tail_case": true,
#       "stances": {
#         "Strait of Hormuz Closure": "bullish",
#         "SPR Intervention": "bullish",
#         "Global Energy Security": "bullish",
#         "US Domestic Production": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently dominated by the geopolitical shock of the Strait of Hormuz closure. My forecast reflects a high-risk environment where prices are elevated due to supply fears, with significant uncertainty regarding the duration of the conflict and the effectiveness of potential SPR releases. The scenarios capture the range from a prolonged, high-price conflict to a potential de-escalation, with a tail case for a catastrophic supply failure."
# }
# predict() failed at origin 2026-03-16 (attempt 1/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, point_forecast (98.00) at horizon 21 deviates from the probability-weighted scenario price (111.75) by 13.75, exceeding the 15%-of-spread tolerance (12.00). The model's point forecast is inconsistent with its own stated scenarios. [type=value_error, input_value={'forecasts': [{'horizon'...rophic supply failure.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 99.5,
#       "quantiles": [
#         { "quantile": 0.05, "value": 92.0 },
#         { "quantile": 0.1, "value": 94.0 },
#         { "quantile": 0.2, "value": 96.5 },
#         { "quantile": 0.3, "value": 98.0 },
#         { "quantile": 0.4, "value": 99.0 },
#         { "quantile": 0.5, "value": 99.5 },
#         { "quantile": 0.6, "value": 101.0 },
#         { "quantile": 0.7, "value": 103.0 },
#         { "quantile": 0.8, "value": 105.5 },
#         { "quantile": 0.9, "value": 108.0 },
#         { "quantile": 0.95, "value": 110.0 }
#       ],
#       "rationale": "The market is in a high-volatility 'crisis-driven bull phase' due to the Strait of Hormuz closure. Short-term price action is dominated by the geopolitical risk premium, overriding the underlying structural surplus. The 5-day horizon reflects extreme sensitivity to any news regarding the conflict or emergency stock releases."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 96.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 85.0 },
#         { "quantile": 0.1, "value": 88.0 },
#         { "quantile": 0.2, "value": 91.0 },
#         { "quantile": 0.3, "value": 93.5 },
#         { "quantile": 0.4, "value": 95.0 },
#         { "quantile": 0.5, "value": 96.0 },
#         { "quantile": 0.6, "value": 98.5 },
#         { "quantile": 0.7, "value": 101.0 },
#         { "quantile": 0.8, "value": 104.0 },
#         { "quantile": 0.9, "value": 107.0 },
#         { "quantile": 0.95, "value": 109.0 }
#       ],
#       "rationale": "By 10 days, the market begins to price in the impact of the IEA's coordinated stock release and the potential for temporary supply-chain workarounds. While the risk premium remains elevated, the extreme panic of the initial shock begins to moderate."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 91.0,
#       "quantiles": [
#         { "quantile": 0.05, "value": 78.0 },
#         { "quantile": 0.1, "value": 81.0 },
#         { "quantile": 0.2, "value": 85.0 },
#         { "quantile": 0.3, "value": 88.0 },
#         { "quantile": 0.4, "value": 90.0 },
#         { "quantile": 0.5, "value": 91.0 },
#         { "quantile": 0.6, "value": 94.0 },
#         { "quantile": 0.7, "value": 97.0 },
#         { "quantile": 0.8, "value": 101.0 },
#         { "quantile": 0.9, "value": 105.0 },
#         { "quantile": 0.95, "value": 108.0 }
#       ],
#       "rationale": "Over a 21-day horizon, the market is expected to shift focus back toward the structural supply-demand surplus, assuming the Strait of Hormuz crisis does not escalate into a broader, long-term regional war. The backwardated curve reflects this expectation of eventual normalization."
#     }
#   ],
#   "factors": [
#     {
#       "name": "Strait of Hormuz Disruption",
#       "category": "geopolitical",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "Global Structural Surplus",
#       "category": "macro",
#       "tier": "core"
#     },
#     {
#       "name": "Emergency Stock Releases",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Crisis Escalation",
#       "probability": 0.25,
#       "price_low": 105.0,
#       "price_high": 125.0,
#       "is_tail_case": true,
#       "stances": {
#         "Strait of Hormuz Disruption": "bullish",
#         "Global Structural Surplus": "neutral",
#         "Emergency Stock Releases": "bearish"
#       }
#     },
#     {
#       "name": "Managed De-escalation",
#       "probability": 0.75,
#       "price_low": 80.0,
#       "price_high": 100.0,
#       "is_tail_case": false,
#       "stances": {
#         "Strait of Hormuz Disruption": "bearish",
#         "Global Structural Surplus": "bearish",
#         "Emergency Stock Releases": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently dominated by the geopolitical risk premium stemming from the Strait of Hormuz closure. My forecast reflects a high-volatility environment where the immediate price is driven by fear, but the medium-term outlook is anchored by the underlying structural surplus and the mitigating effect of emergency stock releases. The scenarios contrast a tail-case escalation against a more likely managed de-escalation."
# }
# predict() failed at origin 2026-03-16 (attempt 2/5): 1 validation error for WtiScenarioForecastOutput
#   Value error, Expected 2-5 core factors, got 1. [type=value_error, input_value={'forecasts': [{'horizon'...managed de-escalation.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/value_error — retrying in 30s
#   News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview) ✓
# 21:08:18 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:11:08 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:13:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e27683b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238f620>, 30209.335207479)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e8c2ddc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2c624e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a4c90>, 30391.12604961)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c63470>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2cb62a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a5b70>, 30379.451926189)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2cb56a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2c63380>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238d630>, 30562.145501129)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c60e30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf887740>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf603930>, 30554.348788725)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc91ae40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc952f00>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1400>, 30730.756900675)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc8f6690>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb71ac0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1b00>, 30724.274088799)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb711c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2373800>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe0980>, 30902.060328086)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc919880>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e24089e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c3b60>, 30892.580343518)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2408680>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb9ee40>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c22e0>, 31072.710868514)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb9cf20>
# 21:16:51 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:19:55 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:22:45 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:25:37 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:28:29 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# 21:31:18 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb9e510>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1d30>, 31065.312866499)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046fa70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d05169c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c0ec0>, 31246.426426224)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb9d1c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e26fd4f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c17f0>, 31424.787919629)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e26fd0d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046ca70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d5710>, 31411.369892128)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046d370>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d04acb90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c2820>, 31239.908583802)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c68ad0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2371fd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96d860>, 31484.013824818)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2370860>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf790320>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf682eb0>, 31477.981057513)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf7909e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc9730b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96c0c0>, 31521.98108267)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e25d0470>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2c68c50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf680440>, 31515.537752506)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c6a330>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046e3c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf681d30>, 31565.977404464)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d046e720>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf991520>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a7380>, 31560.586192069)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf991f40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf93a120>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf682190>, 31613.099203852)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf93b230>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa0ae10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a65f0>, 31605.830835509)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c63e60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa42c90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a4ec0>, 31657.467261039)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa43a40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb721e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a73f0>, 31651.41881308)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb72240>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf8f9b50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a5cc0>, 31694.53092206)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf8fb770>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9ddc70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa33c40>, 31689.265066269)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf9de6f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d0449a90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a71c0>, 31736.365713026)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d04480b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e3066e40>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf683cb0>, 31730.767530273)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e3066ae0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2c603b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc96e7b0>, 31784.296885898)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c62930>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d046f320>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa31d30>, 31774.706787625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2c62540>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf938770>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf680d00>, 31835.038124305)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf93a870>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf9dd4c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa316a0>, 31828.83857763)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e23640b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc9586b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf9a4520>, 31876.625051652)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc95b6e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfbc4860>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa329e0>, 31869.381929706)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfbc7d40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa0bdd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa32ba0>, 31916.215295129)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa09430>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfaff860>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa30280>, 31910.803816581)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa85400>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfa63650>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa311d0>, 31961.808374926)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfa630e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf96c890>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d69e0>, 31952.195314016)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf96cbc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d03fca10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d5cc0>, 32012.154800902)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d03fcb90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e245a4e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe1ef0>, 32002.883739711)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d03fc7d0>
#   CFM Agent v5.2 ✓
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf96eab0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa31e80>, 32060.937876899)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf96d250>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2c688c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf6817f0>, 32052.170555565)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf94d0a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb718b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f4210>, 32108.246081699)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e238ab40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf8f92b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d05d7230>, 32102.780517241)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2388290>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc8f59a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f57f0>, 32149.656733272)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2320050>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfac6840>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238e6d0>, 32142.901811928)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfac7110>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfafd9d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfa31b00>, 32197.064034494)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cfb9ec30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf8f8380>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe32a0>, 32187.268715687)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc983170>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc231670>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f4910>, 32238.29967078)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc231c40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6befc9c10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe38c0>, 32232.532128071)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6befc9580>
#   CFM Agent v5.2.2 (ARIMA only) ✓
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2d6ecc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238ef90>, 32282.35886163)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2d6cfe0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6bef025d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c3bd0>, 32275.928726399)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6bef01a60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e29b0230>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cfbe2e40>, 32325.092314131)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e29b0050>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e29b0710>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c3700>, 32318.214189377)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e29b3770>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e29b2150>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e238cec0>, 32371.414268775)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6d07d31a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2d6c980>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f6120>, 32362.589221266)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2d6e030>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2d6f320>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf680fa0>, 32418.080881339)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2d6d040>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e30645f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c2430>, 32407.211068197)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cf9916a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cfb950a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7b60>, 32467.417191167)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2615820>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e26fd850>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a64a0>, 32456.560049109)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e26fe6f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cf884230>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c1470>, 32521.189715218)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e3064a70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e292f620>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a7070>, 32514.8718408)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e292c980>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e264f1d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a72a0>, 32570.232587126)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e264f410>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e3036030>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a7cb0>, 32561.709298161)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e30369f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc2c6f90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a4670>, 32615.854454529)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc2c6690>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e2ae4830>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc238910>, 32609.438355467)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2ae48f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6d0516a50>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6d04c00c0>, 32675.214305596)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2371400>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e28d59a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f6820>, 32670.084520036)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e28d5a90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6befc87a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7d90>, 32725.685791162)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6befc8350>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc2322a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a7380>, 32719.482441379)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc2326c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e25d1a60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a4600>, 32769.639499267)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e25d2480>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e25d2540>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc2380c0>, 32759.173510184)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e28d5c70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e3036b10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f5c50>, 32815.566374864)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e3034ec0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e29b1d60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f7850>, 32808.097784761)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e29b3200>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6cc2c6900>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cf7f4980>, 32856.150241249)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6cc2c5bb0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e264e360>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc2381a0>, 32850.422185124)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e2616300>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e26b8e90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6e27a7d90>, 32899.195920486)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e29b3530>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fe6e29ac440>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7fe6cc23a190>, 32893.957255288)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7fe6e264d2b0>
#   CFM Agent v5.2.2 Delta-Governed ✓
#
# 2026 evaluation complete.

# %%
# ── Save eval results for NB06 ───────────────────────────────────────────────
# Only baseline predictors are written so uncommenting optional predictors
# above does not add extra rows to the NB06 scorecard.
for _name, _result_dict in eval_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"eval_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in eval_results)} eval result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 eval result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 6. Scorecard
#
# Out-of-sample performance of every active predictor on the 2026 eval period.
# These numbers are the **stateless baseline** the adaptive agent variants must
# beat in Notebook 6 to demonstrate that training added value.

# %%
from energy_oil_forecasting.analysis import score_backtest_results


scorecard_rows = []
for name in PREDICTORS:
    if name not in eval_results:
        continue
    scores = score_backtest_results(eval_results[name], data_service)
    scorecard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS (2026)": scores.get("mean_crps", float("nan")),
            "MAE h=21d (2026)": scores.get("mae_h21", float("nan")),
            "80% CI Coverage": scores.get("coverage_80", float("nan")),
        }
    )

df_scorecard = pd.DataFrame(scorecard_rows).set_index("Predictor")
df_scorecard = df_scorecard.sort_values("Mean CRPS (2026)")

print("━" * 72)
print("2026 EVAL SCORECARD — STATELESS BASELINE:")
print("━" * 72)
print(df_scorecard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2026 EVAL SCORECARD — STATELESS BASELINE:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                               Mean CRPS (2026)  MAE h=21d (2026)  80% CI Coverage
# Predictor
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)          7.779087         10.742400             60.0
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)                   8.170421         10.642740             52.0
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                            8.299662         11.513600             56.0
# CFM Agent v5.2.2 Delta-Governed                                                       8.327229         10.510791             44.0
# CFM Agent v5.2.2 (ARIMA only)                                                         8.494170         10.769797             56.0
# AutoARIMA                                                                             8.500884         10.412689             56.0
# CFM Agent v5.2                                                                        9.155270         11.043407             48.0
# Naive (Last Value)                                                                   10.489200         10.489200              0.0

# %% [markdown]
# ---
# ## 7. Diagnostics — reading past the leaderboard
#
# The scorecard above is a single number per method. That hides *where* the score
# comes from and *whether the ranking is even real*. The next cells decompose it
# straight from the eval predictions — so they recompute on any rerun, smoke or
# full:
#
# - **CRPS by horizon** — does a method win everywhere, or is its mean dominated by
#   one horizon? (For a short forecast, the 5-day calls are easy and nearly tied;
#   the ranking is usually decided by the longest horizon.)
# - **Mean CRPS ± standard error** — with only a handful of origins, are the gaps
#   between methods bigger than the noise, or is the "winner" a coin flip?
#
# With the **smoke spec (2 origins → a few scored points)** expect wide error bars
# and an unstable ranking. That is exactly why a surprising leaderboard here is not
# yet evidence of anything — it is a pipeline check.

# %%
from energy_oil_forecasting import viz
from energy_oil_forecasting.analysis import (
    build_price_frame,
    eval_narrative_md,
    extract_agent_rationales,
    leaderboard_with_uncertainty,
    per_horizon_crps,
    predictions_to_frame,
)
from IPython.display import HTML, Markdown, display  # noqa: A004


# Explode every scored 2026 eval prediction into one tidy row per
# (predictor, origin, horizon): point, 80% interval, realised price, and CRPS.
# Everything in Sections 7–10 reads from this frame, so it all recomputes when
# you flip SMOKE_TEST off and rerun.
price_df = build_price_frame(data_service)
eval_frame = predictions_to_frame(eval_results, data_service)
eval_board = leaderboard_with_uncertainty(eval_frame)
ph_crps = per_horizon_crps(eval_frame)

print("━" * 72)
print("MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):")
print("━" * 72)
print(ph_crps.round(2).to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                                                h=5d  h=10d  h=21d    All
# predictor
# News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)   6.86   4.53  11.23   7.78
# News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)            8.02   5.10  10.71   8.17
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)                     6.94   5.53  11.82   8.30
# CFM Agent v5.2.2 Delta-Governed                                                8.26   5.33  10.73   8.33
# CFM Agent v5.2.2 (ARIMA only)                                                  7.57   5.90  11.44   8.49
# AutoARIMA                                                                      8.25   5.66  10.96   8.50
# CFM Agent v5.2                                                                 8.93   6.19  11.69   9.16
# Naive (Last Value)                                                            10.23   6.96  13.50  10.49

# %%
# Heatmap of the table above. Read it left-to-right: the short-horizon columns
# are usually a near-uniform green (everyone is right), and one long-horizon
# column carries the colour spread that sets the 'All' ranking.
viz.make_crps_heatmap(ph_crps)

# %%
# Same leaderboard, now with a standard-error bar on each mean. If the bars of
# the top methods overlap, their ordering is not statistically distinguishable —
# the honest verdict when only a few origins have been scored.
viz.make_leaderboard_interval_chart(eval_board)

# %% [markdown]
# ---
# ## 8. What are the top methods actually forecasting?
#
# A CRPS number doesn't show *behaviour*. Below, each leading method's **median
# forecast and 80% interval** are drawn against the realised WTI path at every
# eval origin. This is where the leaderboard becomes legible — watch for who
# tracks the move, who simply anchors to the last price, and whose intervals are
# too narrow to cover the outcome when the market jumps.

# %%
# Plot the leaderboard's top methods, and always include the best LLM/agent
# method for contrast (so the chart compares families even when a baseline leads).
_leaders = list(eval_board.index[:3])
_best_llm = next((p for p in eval_board.index if eval_board.loc[p, "family"] == "LLM / Agent"), None)
if _best_llm and _best_llm not in _leaders:
    _leaders.append(_best_llm)
print(f"Showing: {', '.join(_leaders)}")
viz.make_eval_forecast_chart(eval_frame, price_df, _leaders)
# Out:
# Showing: News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview), News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview), News Agent Scenario Schema (gemini-3.1-flash-lite-preview)

# %% [markdown]
# ---
# ## 9. Reading the agent's reasoning
#
# The news-reading agent attaches a free-text **rationale** to every forecast, and
# a link to the full **Langfuse trace**. These are pulled straight from the
# prediction metadata. This is where a surprising score becomes interpretable: you
# can read whether the agent actually saw the geopolitical risk, and *how* it
# turned that into a price and an interval — including, often, an interval far too
# narrow for a regime shift.

# %%
# One card per (agent, origin): the rationale, the per-horizon note, and a link
# to the full reasoning trace. Empty only if no LLM/agent predictor is enabled.
eval_rationales = extract_agent_rationales(eval_results)
display(HTML(viz.render_rationales_html(eval_rationales)))
# Out:
# <div style='max-width:900px'><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-02 &nbsp; point $64.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/d2d2a833e1faf708af5dbf42c4f7ce87' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The market is currently in a transition phase, attempting to reconcile a short-term, supply-constrained environment following severe weather with a bearish medium-term outlook defined by structural surplus. My forecast assumes that the immediate supply-driven price spike will revert, but acknowledges that geopolitical instability provides a persistent floor and a significant tail-risk of sudden volatility.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term momentum is being tested as the market balances the fading impact of Winter Storm Fern with persistent geopolitical risk premiums. Mean reversion toward the $64-$65 range is expected as production normalizes.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-16 &nbsp; point $63.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/c541f4ac0a32d909b15a308a54fa32ba' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The current WTI price action is fundamentally dominated by the elevated risk premium associated with Iran-US tensions in the Middle East. While supply/demand fundamentals are relatively balanced, the uncertainty regarding shipping security in the Strait of Hormuz is creating an asymmetric upside risk. The forecast acknowledges this premium but allows for a reversion to historical norms should the situation stabilize, while maintaining a significant tail-case risk for supply disruptions.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term momentum is heavily skewed by the geopolitical risk premium regarding Iran-US tensions. Prices are expected to hold elevated levels in the 5-day horizon.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-03-02 &nbsp; point $74.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/f42355c25f09b904f004ad69a45e986e' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The market is currently in a state of high uncertainty following the February 28th escalation in the Middle East. The central forecast assumes that while shipping remains severely hampered and risk premiums stay elevated, a full-scale regional war is avoided. However, the probability of price spikes remains high, reflected in the right-skewed quantiles for later horizons.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Prices are reflecting a high risk premium following the late-February geopolitical escalation in the Middle East. Over the next week, the market will likely trade on volatility as intelligence on Strait of Hormuz accessibility emerges. The range is wide to capture both a rapid de-escalation/diplomatic breakthrough (lower end) and a sustained disruption (higher end).</div></div><div style='bo ...

# %% [markdown]
# ---
# ## 10. Takeaways — computed from this run
#
# The summary below is **generated from the eval results in memory, not
# hard-coded**, so it always matches what actually ran: the real winner, whether
# its lead clears the noise floor, the horizon that decided the ranking, the
# best-performing family, and a calibration line. Flip `SMOKE_TEST` off, rerun,
# and these takeaways update themselves with the full leaderboard.

# %%
display(Markdown(eval_narrative_md(eval_frame, smoke=SMOKE_TEST)))
# Out:
# 1. **News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)** has the best mean CRPS (7.78) on the 2026 evaluation, ahead of **News Agent Scenario Schema Anchored (gemini-3.1-flash-lite-preview)** (8.17) by 0.39 — **well within the combined standard error**, so the ranking here is not statistically distinguishable from noise.
# 2. The leaderboard is **decided at h=21d**, where CRPS ranges 0.3–34.4 across methods; at the short h=10d horizon the methods are nearly tied (range 0.2–26.5). A handful of long-horizon points drives the whole ranking.
# 3. **By family** (mean CRPS): LLM / Agent 8.35, Numerical ML 8.50, Baseline 10.49. Best family this window: **LLM / Agent**.
# 4. **Calibration:** News Agent Scenario Schema Enhanced - temp=0 (gemini-3.1-flash-lite-preview)'s 80% interval covered 60% of outcomes (target 80%) over its 25 scored point(s). With this few, coverage this far from target is itself a small-sample artefact, not necessarily mis-calibration.
# 5. Based on 9 origins / 200 scored points.

# %% [markdown]
# ---
# ## 11. What stateless methods can't do
#
# Sections 7–10 score and dissect this run on its own terms. But every method here
# shares one structural limit, independent of who topped the leaderboard: it is
# calibrated (or prompted) **once and never updated between rounds**. That is
# intentional — it creates a clean baseline — but it leaves a systematic gap:
#
# - **No error feedback.** If a method's intervals are consistently too narrow in
#   an elevated-vol regime (read the coverage line in Section 10, and the squashed
#   error bars in Section 8), it keeps making the same mistake. Nothing updates its
#   calibration between origins.
#
# - **No strategy evolution.** Each prediction starts from the same prior — the
#   same fitted model, or the same prompt. Resolved outcomes disappear without
#   influencing future forecasts.
#
# - **Context without memory.** Even the news agent re-reads the world each origin;
#   it does not accumulate what worked. The rationales in Section 9 are written
#   fresh every time, with no record of how the last one resolved.
#
# → **Notebook 5** introduces adaptive agents that study the 2025 backtest, record
# systematic observations, and calibrate their strategies accordingly. At inference
# time, each agent receives the live stateless estimate and decides how to adjust
# it — applying what it learned from training.
#
# → **Notebook 6** evaluates whether any training approach actually improved
# out-of-sample performance on the held-out 2026 data — measured against the
# stateless baseline this notebook just established.

# %%
from aieng.forecasting.methods.agentic.agent_factory import ContextRetrievalConfig
print("verifier_model" in ContextRetrievalConfig.model_fields)
print(ContextRetrievalConfig.model_fields.keys())
# Out:
# True
# dict_keys(['enabled', 'search_model', 'instruction', 'enforce_cutoff', 'temperature', 'max_output_tokens', 'verifier_model', 'verifier_max_attempts', 'verifier_confidence_threshold'])

# %%
import glob, os, datetime
for path in glob.glob("**/data/predictions/**/*scenario_schema*", recursive=True):
    print(datetime.datetime.fromtimestamp(os.path.getmtime(path)), path)
# Out:
# 2026-08-20 06:54:33.409842 data/predictions/scenario_schema_enhanced_consistency_test
# 2026-07-25 16:59:50.483749 data/predictions/energy_oil_eval_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:06:56.632109 data/predictions/energy_oil_eval_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-07-25 16:48:08.773386 data/predictions/energy_oil_backtest_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 21:54:58.047101 data/predictions/consistency_test_run_2/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-19 21:54:36.130130 data/predictions/consistency_test_run_1/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-20 07:53:29.196866 data/predictions/scenario_schema_enhanced_consistency_test/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_forecast.yaml
# 2026-08-19 21:54:14.089158 data/predictions/consistency_test_run_0/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_test.yaml
# 2026-08-19 15:00:36.464605 data/predictions/energy_oil_backtest_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 18:42:02.856250 data/predictions/energy_oil_backtest_10yr_quarterly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:26:18.033594 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-22 19:07:58.271933 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_anchored_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-20 11:48:11.227083 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-22 15:02:38.741133 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-22 21:05:57.383620 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_anchored_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-22 15:02:38.731133 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_enhanced_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml

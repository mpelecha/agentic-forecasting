# %% [markdown]
# # WTI Crude Oil Price Forecasting — Stateless Methods: Systematic Backtest (Notebook 4 of 7)
#
# This notebook simulates a rigorous production forecasting workflow:
#
# 1. Run a **rolling weekly backtest across 2025** using
#    `energy_oil_backtest.yaml` for all candidate predictors.
# 2. Compute metrics — **CRPS** for 5/10/21-day trajectories.
# 3. Select the **top contender configurations** based solely on 2025
#    historical performance (no peeking at 2026).
# 4. Let the contenders compete in the **2026 Protected Arena**
#    (`energy_oil_eval.yaml`) across the geopolitical price shock and its
#    aftermath — measuring adaptive real-time responsiveness and calibration.
#    The eval window runs through the most recent origin whose 21-business-day
#    horizon still resolves against cached data (see `scripts/fetch_wti.py`).
#
# The line-up spans three families behind one `Predictor` interface: **baselines**
# (Naive, AutoARIMA), **numerical ML** (LightGBM ± a leak-safe covariate panel),
# and **LLM/agent** methods (LLM-process forecasters and a news-reading analyst
# agent) — the last run on *both* project models, `gemini-3.1-flash-lite-preview`
# and `gemini-3.5-flash`. Every predictor is one toggle line in the registry in
# Section 2. Agent configs come from `energy_oil_forecasting.analyst_agent`.

# %% [markdown]
# ---
# ## 1. Setup, Data Registration & Spec Loading

# %%
import warnings
from pathlib import Path

import energy_oil_forecasting
import pandas as pd
import yaml
from aieng.forecasting.evaluation import (
    MultiTargetBacktestSpec,
    cached_multi_backtest,
    describe_spec,
)
from aieng.forecasting.models import ADVANCED_MODEL, LITE_MODEL
from energy_oil_forecasting.data import (
    DEFAULT_WTI_COVARIATE_SERIES_IDS,
    build_wti_multivariate_service,
)


warnings.filterwarnings("ignore")

# ── Mode ──────────────────────────────────────────────────────────────────────
# Set SMOKE_TEST = True to run a 2-origin, 1-sample version of the notebook
# for fast local development and end-to-end CI testing. The full specs run
# 51 backtest + 8 eval origins; smoke runs 2 + 2.
SMOKE_TEST = False 

# ── Models ────────────────────────────────────────────────────────────────────
# The project standardises on two Vector-proxy models. Every LLM and agent
# predictor below is run once per model so we can compare them head-to-head.
# (bare proxy names — no "gemini/" prefix)
MODELS = [LITE_MODEL, ADVANCED_MODEL]  # "gemini-3.1-flash-lite-preview", "gemini-3.5-flash"

# ── Derived settings (do not edit below) ─────────────────────────────────────
N_SAMPLES = 1 if SMOKE_TEST else 3  # trajectories per LLMP-Sampled call

# LightGBM hyperparameters (shared by the univariate and +covariate variants).
LAGS = 21  # one trading month of lagged target/covariate history
NUM_SAMPLES_LGBM = 100 if SMOKE_TEST else 200  # Monte-Carlo draws for quantiles
LGBM_KWARGS = {"num_threads": 1, "n_jobs": 1, "verbosity": -1}  # deterministic, quiet

# Data service: WTI target + a leak-safe covariate panel (all Yahoo Finance —
# Brent, natural gas, gasoline, gold, USD index, the USL/USO futures-curve
# contango proxy, and VIX). Non-covariate predictors simply ignore the extras,
# so one service feeds the whole leaderboard. Unavailable tickers are skipped
# with a warning, so this still runs offline / under partial connectivity.
data_service = build_wti_multivariate_service()
COVARIATES = [c for c in DEFAULT_WTI_COVARIATE_SERIES_IDS if c in set(data_service.series_ids)]

spec_dir = Path(energy_oil_forecasting.__file__).parent / "specs"
if SMOKE_TEST:
    backtest_file, eval_file = "energy_oil_smoke.yaml", "energy_oil_eval_smoke.yaml"
else:
    backtest_file, eval_file = "energy_oil_backtest.yaml", "energy_oil_eval.yaml"

with open(spec_dir / backtest_file) as f:
    backtest_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))
with open(spec_dir / eval_file) as f:
    eval_spec = MultiTargetBacktestSpec.model_validate(yaml.safe_load(f))



# ── Reduce origin frequency + give this window its own cache namespace ─────
# spec_id now depends on SMOKE_TEST too, so toggling smoke/full never collides
# with (or silently reuses) the other mode's cached results.
_suffix = "_smoke" if SMOKE_TEST else ""

#backtest_spec.stride = 21  # ~monthly → ~12 origins instead of 51 (full mode)
backtest_spec.stride = 10  # ~biweekly → ~26 origins instead of 51 (full mode)
backtest_spec.spec_id = f"energy_oil_backtest_biweekly{_suffix}"

#eval_spec.stride = 21      # ~monthly → ~5 origins instead of 18 (full mode)
eval_spec.stride = 10      # ~biweekly → ~9 origins instead of 18 (full mode)
eval_spec.spec_id = f"energy_oil_eval_biweekly{_suffix}"





print(f"{'⚡ SMOKE MODE' if SMOKE_TEST else '📊 FULL MODE'} — MODELS={MODELS}  N_SAMPLES={N_SAMPLES}")
print(f"Covariates registered ({len(COVARIATES)}): {', '.join(COVARIATES) or '(none)'}")
print()
print("━" * 72)
print("LOADED SPECIFICATIONS:")
print("━" * 72)
print(describe_spec(backtest_spec, data_service))
print(describe_spec(eval_spec, data_service))
# Out:
# 📊 FULL MODE — MODELS=['gemini-3.1-flash-lite-preview', 'gemini-3.5-flash']  N_SAMPLES=3
# Covariates registered (7): brent_log_ret_1b_l1b, natgas_log_ret_1b_l1b, gasoline_log_ret_1b_l1b, gold_log_ret_1b_l1b, dollar_index_log_ret_1b_l1b, oil_curve_contango_l1b, vix_level_l1b
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# LOADED SPECIFICATIONS:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MultiTargetBacktestSpec (spec_id=energy_oil_backtest_biweekly)
#   description: Weekly rolling backtest in 2025 for daily WTI crude oil price forecasting. Evaluates trajectory forecasts (5, 10, 21 business days) with CRPS/MAE and binary up-shock forecasts (climb > $5 in 5 business days) with Brier Score. Used to select the top contender models.
#   start:       2025-01-06 00:00:00
#   end:         2025-12-22 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B
#
# MultiTargetBacktestSpec (spec_id=energy_oil_eval_biweekly)
#   description: Prospective/out-of-sample evaluation period in 2026 for daily WTI crude oil. Evaluates selected contender models on 18 weekly origins from the early 2026 geopolitical price shock through its aftermath, to measure adaptive real-time forecasting performance.
#   start:       2026-02-02 00:00:00
#   end:         2026-06-01 00:00:00
#   stride:      10
#   warmup:      250
#   tasks:       1
#
# Task: wti_oil_price_forecast
#   description: WTI Crude Oil continuous front-month futures Close price (yfinance symbol: CL=F), projected 5, 10, and 21 trading days ahead.
#   horizons:    [5, 10, 21] (len=3)
#   frequency:   B
#   payload:     continuous
#   resolution:  observed_value_at_resolution_timestamp
# - target_series_id: wti_crude_oil_price
#     description:    WTI Crude Oil continuous front-month futures adjusted close (Yahoo Finance CL=F)
#     source:         yfinance
#     units:          USD/bbl
#     frequency:      B

# %% [markdown]
# ---
# ## 2. Candidate Predictors
#
# This experiment puts a full slate of methods on the same `Predictor` interface and
# the same rolling backtest, spanning three families:
#
# | Family | Predictors | Role |
# |---|---|---|
# | **Baselines** | `Naive (Last Value)`, `AutoARIMA` | Carry-forward floor + the classical statistical anchor |
# | **Numerical ML** | `LightGBM`, `LightGBM + cov` (+ optional `Prophet`) | Gradient-boosted quantile regression on lagged price (and a leak-safe covariate panel — Brent, gas, gasoline, gold, USD index, the futures-curve contango proxy, and VIX). LightGBM-with-covariates was the strongest method in the S&P 500 study. |
# | **LLM / Agent** | `LLMP-Sampled`, `LLMP-Grid`, `News Agent` — each on **both** project models | LLM-process forecasters and a news-reading analyst agent, run on `gemini-3.1-flash-lite-preview` *and* `gemini-3.5-flash` |
#
# The predictor cell below is a **registry**: every method is one line with an
# `enabled` flag. Flip a flag to add or drop a predictor — the rest of the
# notebook (backtest, scoring, eval, scorecard) iterates over whatever is active.
# The two baselines are flagged `baseline=True` and are the only results written to
# `adaptive_agent/curriculum/` for Notebooks 5–6, so toggling the others never
# disturbs the downstream training data.

# %%
from dataclasses import dataclass
from typing import Callable

from aieng.forecasting.methods import (
    LastValuePredictor,
    QuantileGridLLMPredictor,
    QuantileGridLLMPredictorConfig,
    SampledTrajectoryLLMPredictor,
    SampledTrajectoryLLMPredictorConfig,
)
from aieng.forecasting.methods.numerical.darts_arima import DartsAutoARIMAPredictor
from aieng.forecasting.methods.numerical.darts_regression import DartsLightGBMPredictor
from energy_oil_forecasting.analyst_agent import (
    build_wti_agent_predictor,
    build_wti_news_config,
    build_wti_news_contrarian_config,
    build_wti_news_factors_v2_config,
    build_wti_news_scenario_schema_config,
    build_wti_scenario_schema_predictor,
)
from energy_oil_forecasting.cfm_agent_v_5_2 import (
    build_cfm_agent_config,
    build_cfm_agent_predictor,
)
from energy_oil_forecasting.prophet_baseline import ProphetPredictor


@dataclass
class PredictorEntry:
    """One row in the experiment. Flip ``enabled`` to switch a predictor on/off."""

    name: str
    factory: Callable[[], object]  # lazy — built only when enabled
    enabled: bool = True
    baseline: bool = False  # baselines are saved to curriculum/ for NB05–06


# LLM / agent factories — each takes a model so the same recipe runs on both.
# LLMP-Sampled optionally serializes the covariate panel into the prompt
# (labeled exogenous-series blocks); the others are target-only. A distinct
# variant_tag keeps the +cov run separate in the cache and on the leaderboard.
def _llmp_sampled(model, covariates=None):
    return SampledTrajectoryLLMPredictor(
        SampledTrajectoryLLMPredictorConfig(
            model=model,
            n_samples=N_SAMPLES,
            covariate_series_ids=covariates,
            variant_tag="cov" if covariates else None,
        )
    )


def _llmp_grid(model):
    return QuantileGridLLMPredictor(QuantileGridLLMPredictorConfig(model=model))


#def _news_agent(model):
#    return build_wti_agent_predictor(build_wti_news_config(model=model))


#def _news_agent_contrarian(model):
#    return build_wti_agent_predictor(build_wti_news_contrarian_config(model=model))


def _news_agent(model):
    return build_wti_agent_predictor(
        build_wti_news_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                              )
    )


def _news_agent_contrarian(model):
    return build_wti_agent_predictor(
        build_wti_news_contrarian_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )


def _news_agent_factors_v2(model):
    return build_wti_agent_predictor(
        build_wti_news_factors_v2_config(model=model, verifier_max_attempts=1, verifier_confidence_threshold=6
                                         )
    )

def _news_agent_scenario_schema(model):
    return build_wti_scenario_schema_predictor(
        build_wti_news_scenario_schema_config(model=model)
    )

def _cfm_agent_v_5_2():
    config = build_cfm_agent_config()
    return build_cfm_agent_predictor(config)


# ── Experiment registry ───────────────────────────────────────────────────────
# Toggle `enabled` on any line to include/exclude that predictor. LLM and agent
# methods are listed once per model so each can be switched on/off individually.
REGISTRY = [
    # Baselines — always saved to curriculum/ for the adaptive-agent notebooks.
    PredictorEntry("Naive (Last Value)", LastValuePredictor, enabled=True, baseline=True),
    PredictorEntry("AutoARIMA", DartsAutoARIMAPredictor, enabled=True, baseline=True),
    # Numerical ML — LightGBM was the strongest method in the S&P 500 study.
    PredictorEntry(
        "LightGBM",
        lambda: DartsLightGBMPredictor(lags=LAGS, num_samples=NUM_SAMPLES_LGBM, lgbm_kwargs=LGBM_KWARGS),
        enabled=False,
    ),
    PredictorEntry(
        "LightGBM + cov",
        lambda: DartsLightGBMPredictor(
            lags=LAGS,
            lags_past_covariates=LAGS,
            covariate_series_ids=COVARIATES,
            num_samples=NUM_SAMPLES_LGBM,
            lgbm_kwargs=LGBM_KWARGS,
        ),
        enabled=False,
    ),
    PredictorEntry("Prophet", ProphetPredictor, enabled=False),
    # LLM processes and the news agent — one row per model in MODELS.
    PredictorEntry(f"LLMP-Sampled ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Sampled ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL), enabled=False),
    # LLMP-Sampled with the covariate panel serialized into the prompt — the one
    # LLM method that can take covariates with no package change. Compare each of
    # these against its target-only twin above to see if context helps the LLM.
    PredictorEntry(f"LLMP-Sampled + cov ({LITE_MODEL})", lambda: _llmp_sampled(LITE_MODEL, COVARIATES), enabled=False),
    PredictorEntry(
        f"LLMP-Sampled + cov ({ADVANCED_MODEL})", lambda: _llmp_sampled(ADVANCED_MODEL, COVARIATES), enabled=False
    ),
    PredictorEntry(f"LLMP-Grid ({LITE_MODEL})", lambda: _llmp_grid(LITE_MODEL), enabled=False),
    PredictorEntry(f"LLMP-Grid ({ADVANCED_MODEL})", lambda: _llmp_grid(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({LITE_MODEL})", lambda: _news_agent(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent ({ADVANCED_MODEL})", lambda: _news_agent(ADVANCED_MODEL), enabled=False),
    PredictorEntry(f"News Agent Contrarian ({LITE_MODEL})", lambda: _news_agent_contrarian(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Factors V2 ({LITE_MODEL})", lambda: _news_agent_factors_v2(LITE_MODEL), enabled=False),
    PredictorEntry(f"News Agent Scenario Schema ({LITE_MODEL})", lambda: _news_agent_scenario_schema(LITE_MODEL), enabled=True),
    PredictorEntry("CFM Agent v5.2", _cfm_agent_v_5_2, enabled=True),

]

# Instantiate only the enabled predictors (lazy factories skip the rest).
PREDICTORS = {e.name: e.factory() for e in REGISTRY if e.enabled}
_BASELINE_PREDICTORS = {e.name for e in REGISTRY if e.baseline}

print(f"Active predictors ({len(PREDICTORS)}):")
for name in PREDICTORS:
    tag = "  (baseline → curriculum/)" if name in _BASELINE_PREDICTORS else ""
    print(f"  {name}{tag}")
# Out:
# Active predictors (4):
#   Naive (Last Value)  (baseline → curriculum/)
#   AutoARIMA  (baseline → curriculum/)
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview)
#   CFM Agent v5.2

# %% [markdown]
# ---
# ## 3. Run the 2025 Historical Backtest
#
# All 51 weekly origins in 2025 are evaluated for each predictor.
# `cached_multi_backtest` caches results under `data/predictions/` so
# subsequent runs are instant.

# %%
import time

print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
print("LLM/agent runs are expensive — first run will take several minutes.\n")

backtest_results: dict[str, object] = {}
for i, (_name, _predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)  # pace between predictors, not just after a failure
    backtest_results[_name] = cached_multi_backtest(
        _predictor, backtest_spec, data_service,
        max_retries=4,     # was 2
        retry_delay=30.0,  # was 2.0 — long enough to clear an RPM window
        force_refresh=False, #(_name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {_name} ✓")

print("\nAll 2025 backtests complete.")

#print(f"Running 2025 rolling backtest ({len(PREDICTORS)} predictor(s))...")
#print("LLM/agent runs are expensive — first run will take several minutes.\n")
#
#backtest_results: dict[str, object] = {}
#for _name, _predictor in PREDICTORS.items():
#    backtest_results[_name] = cached_multi_backtest(_predictor, backtest_spec, data_service)
#    print(f"  {_name} ✓")
#
#print("\nAll 2025 backtests complete.")
# Out:
# Running 2025 rolling backtest (4 predictor(s))...
# LLM/agent runs are expensive — first run will take several minutes.
#
#   Naive (Last Value) ✓
#   AutoARIMA ✓
# Raw agent response (schema validation failed):
# {
#   "forecasts": [
#     {
#       "horizon": 5,
#       "point_forecast": 69.5,
#       "quantiles": [
#         {"quantile": 0.05, "value": 66.5},
#         {"quantile": 0.1, "value": 67.2},
#         {"quantile": 0.2, "value": 67.8},
#         {"quantile": 0.3, "value": 68.5},
#         {"quantile": 0.4, "value": 69.0},
#         {"quantile": 0.5, "value": 69.5},
#         {"quantile": 0.6, "value": 70.1},
#         {"quantile": 0.7, "value": 70.8},
#         {"quantile": 0.8, "value": 71.5},
#         {"quantile": 0.9, "value": 72.2},
#         {"quantile": 0.95, "value": 72.8}
#       ],
#       "rationale": "Short-term consolidation as market digests late-March inventory builds and geopolitical noise surrounding North American trade tariffs."
#     },
#     {
#       "horizon": 10,
#       "point_forecast": 70.2,
#       "quantiles": [
#         {"quantile": 0.05, "value": 65.5},
#         {"quantile": 0.1, "value": 66.8},
#         {"quantile": 0.2, "value": 67.9},
#         {"quantile": 0.3, "value": 69.1},
#         {"quantile": 0.4, "value": 69.6},
#         {"quantile": 0.5, "value": 70.2},
#         {"quantile": 0.6, "value": 70.8},
#         {"quantile": 0.7, "value": 71.7},
#         {"quantile": 0.8, "value": 72.9},
#         {"quantile": 0.9, "value": 74.0},
#         {"quantile": 0.95, "value": 75.0}
#       ],
#       "rationale": "Moderate recovery likely as initial shock of trade policy shifts begins to price in, tempered by ongoing OPEC+ monitoring."
#     },
#     {
#       "horizon": 21,
#       "point_forecast": 71.0,
#       "quantiles": [
#         {"quantile": 0.05, "value": 64.0},
#         {"quantile": 0.1, "value": 65.5},
#         {"quantile": 0.2, "value": 67.2},
#         {"quantile": 0.3, "value": 68.9},
#         {"quantile": 0.4, "value": 70.1},
#         {"quantile": 0.5, "value": 71.0},
#         {"quantile": 0.6, "value": 72.3},
#         {"quantile": 0.7, "value": 73.8},
#         {"quantile": 0.8, "value": 75.5},
#         {"quantile": 0.9, "value": 77.2},
#         {"quantile": 0.95, "value": 78.5}
#       ],
#       "rationale": "Increased uncertainty over the month horizon, with wider confidence intervals reflecting potential for either demand-side disappointment or successful OPEC+ supply rebalancing."
#     }
#   ],
#   "factors": [
#     {
#       "name": "OPEC+ Supply Management",
#       "category": "core"
#     },
#     {
#       "name": "Global Demand Growth Trends",
#       "category": "core"
#     },
#     {
#       "name": "US-North America Trade Tensions",
#       "category": "macro",
#       "tier": "transitory",
#       "impact_score": "high"
#     },
#     {
#       "name": "US Crude Inventory Volatility",
#       "category": "financial",
#       "tier": "transitory",
#       "impact_score": "medium"
#     }
#   ],
#   "scenarios": [
#     {
#       "name": "Base Case: Balanced Adjustment",
#       "probability": 0.5,
#       "price_low": 68.0,
#       "price_high": 72.0,
#       "is_tail_case": false,
#       "stances": {
#         "OPEC+ Supply Management": "neutral",
#         "Global Demand Growth Trends": "neutral",
#         "US-North America Trade Tensions": "neutral",
#         "US Crude Inventory Volatility": "neutral"
#       }
#     },
#     {
#       "name": "Bearish: Demand Erosion & Inventory Build",
#       "probability": 0.3,
#       "price_low": 63.0,
#       "price_high": 67.5,
#       "is_tail_case": false,
#       "stances": {
#         "OPEC+ Supply Management": "bearish",
#         "Global Demand Growth Trends": "bearish",
#         "US-North America Trade Tensions": "bearish",
#         "US Crude Inventory Volatility": "bearish"
#       }
#     },
#     {
#       "name": "Tail Case: Supply Disruption Risk",
#       "probability": 0.2,
#       "price_low": 73.0,
#       "price_high": 80.0,
#       "is_tail_case": true,
#       "stances": {
#         "OPEC+ Supply Management": "bullish",
#         "Global Demand Growth Trends": "bullish",
#         "US-North America Trade Tensions": "bullish",
#         "US Crude Inventory Volatility": "bullish"
#       }
#     }
#   ],
#   "rationale": "The market is currently wrestling with conflicting signals: bearish physical indicators (inventory builds) and geopolitical volatility (trade tariffs). The forecast reflects a cautious wait-and-see approach, with a slight upward drift assuming trade tensions do not escalate into a prolonged supply disruption and that OPEC+ maintains discipline."
# }
# predict() failed at origin 2025-03-31 (attempt 1/5): 4 validation errors for WtiScenarioForecastOutput
# factors.0.category
#   Input should be 'macro', 'financial' or 'geopolitical' [type=literal_error, input_value='core', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/literal_error
# factors.0.tier
#   Field required [type=missing, input_value={'name': 'OPEC+ Supply Ma...nt', 'category': 'core'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
# factors.1.category
#   Input should be 'macro', 'financial' or 'geopolitical' [type=literal_error, input_value='core', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/literal_error
# factors.1.tier
#   Field required [type=missing, input_value={'name': 'Global Demand G...ds', 'category': 'core'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing — retrying in 30s
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
# 15:28:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:32:13 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:35:20 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:38:34 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:41:41 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:44:49 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:47:57 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:51:02 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:54:04 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 15:57:12 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:00:29 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:03:36 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:06:48 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:10:05 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:13:14 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:16:25 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:19:36 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:22:41 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:25:51 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:28:58 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9b179d60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9b195550>, 6858.719984937)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9b391d00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9b0eff80>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9afb3310>, 6854.379961492)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9b4e98b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9afd9430>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9afb31c0>, 6864.962436311)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9afdaff0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a60b500>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60cc20>, 6869.665839002)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a60b7a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6bbb00>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60d630>, 6881.369455878)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6bb830>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6bb800>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60c0c0>, 6876.467426421)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6baf60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6f9c10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60e040>, 6892.66121969)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6fa5d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6f8ad0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60e890>, 6887.769397471)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6faf60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9b19ea20>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60e660>, 6903.171237172)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9b19ef90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a680bf0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60f1c0>, 6898.705917307)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a681430>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6f8350>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60eac0>, 6913.75236017)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6fbbc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a642240>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60faf0>, 6909.453264203)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6427e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a642150>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a650130>, 6924.017350709)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6413d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a641dc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a650910>, 6919.688393231)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a643770>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6fb590>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a650050>, 6965.935125255)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6f8f20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a667650>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a650b40>, 6961.302948167)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6676b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a642c00>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a651630>, 6976.843429722)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a641220>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5811c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a651da0>, 6971.987502638)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a580aa0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a582660>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a6529e0>, 6988.945575877)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5807a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5c8950>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a6526d0>, 6984.581774485)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5c8710>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5c9550>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a653460>, 6999.195000066)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5cb710>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5cb620>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a6535b0>, 6995.073778318)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5cb0e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a665eb0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a6531c0>, 7010.900849985)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a664590>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5f3170>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a5281a0>, 7006.204199981)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5f30b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5f3e30>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a528750>, 7022.393594493)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5f3440>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5f37a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a5286e0>, 7017.483474423)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a6672c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5064e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a5291d0>, 7033.734981963)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a580ce0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a574170>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a529390>, 7028.881665914)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a574e00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a576e40>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a529c50>, 7045.397739923)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a576570>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5743e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a529e10>, 7040.308695177)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5742c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a49a6c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a5288a0>, 7055.731980571)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a499dc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a49abd0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a52a5f0>, 7051.723552953)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a49b620>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5763f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a52a430>, 7067.161686701)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a576780>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a4c9f70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a52acf0>, 7062.315740039)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a4ca540>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a4c8110>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a52b620>, 7078.350770307)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a4c9850>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a4cbbc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a52b930>, 7073.681463561)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a4c9b50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a48efc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a470670>, 7089.21024941)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a48d0a0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a48deb0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a470830>, 7084.831754993)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a48f710>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a420320>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a470ec0>, 7099.56142604)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5f1cd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a421070>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a470ad0>, 7095.051865834)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a4216d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a48c6b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a4716a0>, 7110.654810592)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a48ffe0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a45d1f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a471860>, 7106.229118998)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a45c5c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a45c320>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a471710>, 7121.711832205)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a45c920>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a45d910>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a471a20>, 7117.020802423)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a45eff0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a38a7b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a472580>, 7131.861597475)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a38a690>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a38ab70>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a472820>, 7127.781479481)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a38acc0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a420c80>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a472890>, 7141.936794565)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a423740>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a3c2540>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a472d60>, 7137.440575611)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3c1220>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a3c1280>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a4739a0>, 7153.056522462)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3c1490>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a3d4a10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f00c0>, 7148.982920936)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3d53d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a3d7e90>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f04b0>, 7164.4734594)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3d7170>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a32c1d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f0670>, 7160.195843984)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a32c9e0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a32f440>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f11d0>, 7177.607158359)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a32f020>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a32cb60>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f1390>, 7172.752691878)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a32e9f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a321760>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a22f000>, 7383.71744034)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3210d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99db63f0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a22faf0>, 7375.655049115)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d99db72c0>
# 16:32:15 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:35:26 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:38:36 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:41:50 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:44:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:48:06 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99de1df0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a22f230>, 7573.037948916)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d99de3ef0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a5f16d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f1da0>, 7566.321226973)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5f15b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a60a0c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f2350>, 7760.223141678)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a60a900>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99db40e0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a653b60>, 7755.123983797)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a00c3b0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99db50d0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a60c6e0>, 7947.357812514)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d99db4260>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc54890>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9be8e430>, 7939.822439376)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9bc57380>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a18c2c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a1780c0>, 8142.164099509)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a18f050>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc814c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a179010>, 8135.428894698)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9bc56540>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc81460>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a179a90>, 8329.543608125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a5c8260>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc49430>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a17a0b0>, 8323.531889527)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9bc49ac0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9ba297c0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a473000>, 8516.309722877)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9ba2b290>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1da2489dc0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a529be0>, 8507.259392471)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a3c39b0>
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#   CFM Agent v5.2 ✓
#
# All 2025 backtests complete.

# %% [markdown]
# ---
# ## 4. Performance Characterisation
#
# We score every active predictor on the 2025 backtest data:
# - **CRPS** (Continuous Ranked Probability Score) — sharpness + calibration combined
# - **MAE at h=21d** — point forecast accuracy at the longest horizon
#
# The leaderboard ranks the families against each other — how much structure the
# numerical methods (AutoARIMA, LightGBM ± covariates) extract over the naive
# floor, whether the covariate panel earns its keep, and how the LLM/agent methods
# compare across the two models. Where each method wins and where it struggles in
# 2025 is exactly the material the adaptive agent learns from in Notebook 5.

# %%
import math

from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []
for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    leaderboard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS": scores.get("mean_crps", float("nan")),
            "MAE h=21d": scores.get("mae_h21", float("nan")),
        }
    )

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print("2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:")
print("━" * 72)
print(df_leaderboard.to_string())

arima_crps = df_leaderboard.loc["AutoARIMA", "Mean CRPS"] if "AutoARIMA" in df_leaderboard.index else float("nan")
naive_crps = (
    df_leaderboard.loc["Naive (Last Value)", "Mean CRPS"]
    if "Naive (Last Value)" in df_leaderboard.index
    else float("nan")
)
if not math.isnan(arima_crps):
    print(
        f"\nAutoARIMA CRPS improvement over Naive: {naive_crps - arima_crps:.4f} ({(naive_crps - arima_crps) / naive_crps:.1%})"
    )
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 HISTORICAL BACKTEST — PERFORMANCE SUMMARY:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                             Mean CRPS  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)   2.023526   2.750811
# CFM Agent v5.2                                               2.122313   2.859812
# AutoARIMA                                                    2.504927   3.007586
# Naive (Last Value)                                           3.002162   3.002162
#
# AutoARIMA CRPS improvement over Naive: 0.4972 (16.6%)

# %%
import math
import numpy as np
import pandas as pd
from datetime import datetime
from aieng.forecasting.evaluation.prediction import ContinuousForecast
from energy_oil_forecasting.analysis import score_backtest_results


leaderboard_rows = []

for name, results in backtest_results.items():
    scores = score_backtest_results(results, data_service)
    
    # Per-horizon MAE breakdown (instead of blended mae_h21)
    horizon_errors: dict[int, list[float]] = {h: [] for h in backtest_spec.tasks[0].horizons}
    for result in results.values():
        task = result.spec.task
        offset = pd.tseries.frequencies.to_offset(task.frequency)
        actual_df = data_service.get_series(task.target_series_id, as_of=datetime.now())
        actual_by_date = {
            pd.Timestamp(row["timestamp"]).normalize(): float(row["value"]) for _, row in actual_df.iterrows()
        }
        for pred in result.predictions:
            if not isinstance(pred.payload, ContinuousForecast):
                continue
            fd = pd.Timestamp(pred.forecast_date).normalize()
            actual = actual_by_date.get(fd)
            if actual is None:
                continue
            as_of = pd.Timestamp(pred.as_of)
            for h in task.horizons:
                if (as_of + offset * h).normalize() == fd:
                    horizon_errors[h].append(abs(pred.payload.point_forecast - actual))
                    break

    row = {
        "Predictor": name,
        "Mean CRPS": scores.get("mean_crps", float("nan")),
        "80% CI Coverage": scores.get("coverage_80", float("nan")),
    }
    for h in backtest_spec.tasks[0].horizons:
        errs = horizon_errors[h]
        row[f"MAE h={h}d"] = float(np.mean(errs)) if errs else float("nan")
    leaderboard_rows.append(row)

df_leaderboard = pd.DataFrame(leaderboard_rows).set_index("Predictor")
df_leaderboard = df_leaderboard.sort_values("Mean CRPS")

print("━" * 72)
print(f"2025 BACKTEST — PERFORMANCE BY HORIZON:")
print("━" * 72)
print(df_leaderboard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2025 BACKTEST — PERFORMANCE BY HORIZON:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                             Mean CRPS  80% CI Coverage  MAE h=5d  MAE h=10d  MAE h=21d
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)   2.023526        70.270270  2.603462   2.508636   3.103077
# CFM Agent v5.2                                               2.122313        85.135135  2.735887   2.603968   3.200219
# AutoARIMA                                                    2.504927        91.891892  2.829270   2.800086   3.361480
# Naive (Last Value)                                           3.002162         0.000000  2.750770   2.741364   3.474231

# %%
# ── Save backtest results for NB05 / NB06 ────────────────────────────────────
# Only the baseline predictors (flagged in the registry above) are written to
# curriculum/ so that toggling the other predictors on/off does not change the
# files NB05 and NB06 depend on.
_CURRICULUM_DIR = Path("adaptive_agent/curriculum")
_CURRICULUM_DIR.mkdir(exist_ok=True)
for _name, _result_dict in backtest_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"backtest_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in backtest_results)} backtest result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 backtest result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 5. 2026 Evaluation — Held-Out Test Period
#
# We run every active predictor on **18 weekly origins spanning Feb–Jun 2026**
# (`energy_oil_eval.yaml`) — the major geopolitical volatility spike not seen
# during the 2025 backtest, plus its aftermath. The window runs through the
# most recent origin that still fully resolves against cached WTI data (the
# 21-business-day horizon needs data 21 business days past the origin).
#
# This evaluation serves two purposes:
# 1. **Measure out-of-sample robustness** — do the 2025 edges (statistical,
#    covariate, or LLM/agent) hold under a structural regime shift?
# 2. **Establish the stateless baseline** that the trained adaptive agents in
#    Notebook 6 are compared against. The baseline predictors' results are saved
#    to `adaptive_agent/curriculum/` for Notebooks 5 and 6 to load.

# %%
import time

print("Running 2026 evaluation...")
eval_results: dict[str, object] = {}
for i, (name, predictor) in enumerate(PREDICTORS.items()):
    if i > 0:
        time.sleep(15)
    eval_results[name] = cached_multi_backtest(
        predictor, eval_spec, data_service,
        max_retries=4,
        retry_delay=30.0,
        force_refresh=False, #(name.startswith("News Agent Scenario Schema")),
    )
    print(f"  {name} ✓")

print("\n2026 evaluation complete.")

#print("Running 2026 evaluation...")
#eval_results: dict[str, object] = {}
#for name, predictor in PREDICTORS.items():
#    eval_results[name] = cached_multi_backtest(predictor, eval_spec, data_service)
#    print(f"  {name} ✓")

#print("\n2026 evaluation complete.")
# Out:
# Running 2026 evaluation...
#   Naive (Last Value) ✓
#   AutoARIMA ✓
#   News Agent Scenario Schema (gemini-3.1-flash-lite-preview) ✓
# 16:53:53 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 16:56:59 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99de3890>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a17b770>, 8700.163991242)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d99de3fe0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dad794230>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a1144b0>, 8691.726897977)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad797980>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a18fa10>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a115080>, 8887.189396919)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad7c8d70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a1a7050>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a1157f0>, 8877.500466707)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad8369f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a0a7ce0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a116900>, 9076.929416296)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a0a6db0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a066150>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a00c0>, 9069.71617584)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a0643b0>
# 17:00:09 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 17:03:24 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 17:06:55 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 17:10:08 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 17:13:16 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
# 17:16:35 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dadab9940>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f2270>, 9269.025668051)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dadab8800>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99db6960>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a179390>, 9260.529111884)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d99db4470>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a3899a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a114360>, 9462.002537721)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad836720>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a18c920>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a1080>, 9450.942307576)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a18ec60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a244650>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a1e80>, 9662.010282748)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a48de50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dad7c9160>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a3000>, 9650.915502228)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a1e5940>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc76870>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a3af0>, 9851.015419154)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9bc77ad0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9bc750a0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9bce83d0>, 9840.531589461)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9bc77f20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dad6e4410>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9bce9320>, 10032.564404474)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad6d04d0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dad3d39b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9bcea350>, 10026.100278266)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad3d29c0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1dad3d3da0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a0a12b0>, 10231.089729153)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad3d0d70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d99d4c3b0>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a3f2200>, 10224.845976544)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a244c50>
# 17:19:56 - LiteLLM:ERROR: logging_worker.py:104 - LoggingWorker error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/coder/agentic-forecasting/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/logging_worker.py", line 99, in _process_log_task
#     await asyncio.wait_for(
#   File "/usr/lib/python3.12/asyncio/tasks.py", line 519, in wait_for
#     async with timeouts.timeout(timeout):
#   File "/usr/lib/python3.12/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#   CFM Agent v5.2 ✓
#
# 2026 evaluation complete.

# %%
# ── Save eval results for NB06 ───────────────────────────────────────────────
# Only baseline predictors are written so uncommenting optional predictors
# above does not add extra rows to the NB06 scorecard.
for _name, _result_dict in eval_results.items():
    if _name not in _BASELINE_PREDICTORS:
        continue
    _result = next(iter(_result_dict.values()))
    (_CURRICULUM_DIR / f"eval_{_name}.json").write_text(_result.model_dump_json(), encoding="utf-8")
print(f"Saved {sum(n in _BASELINE_PREDICTORS for n in eval_results)} eval result(s) to {_CURRICULUM_DIR}/")
# Out:
# Saved 2 eval result(s) to adaptive_agent/curriculum/

# %% [markdown]
# ---
# ## 6. Scorecard
#
# Out-of-sample performance of every active predictor on the 2026 eval period.
# These numbers are the **stateless baseline** the adaptive agent variants must
# beat in Notebook 6 to demonstrate that training added value.

# %%
from energy_oil_forecasting.analysis import score_backtest_results


scorecard_rows = []
for name in PREDICTORS:
    if name not in eval_results:
        continue
    scores = score_backtest_results(eval_results[name], data_service)
    scorecard_rows.append(
        {
            "Predictor": name,
            "Mean CRPS (2026)": scores.get("mean_crps", float("nan")),
            "MAE h=21d (2026)": scores.get("mae_h21", float("nan")),
            "80% CI Coverage": scores.get("coverage_80", float("nan")),
        }
    )

df_scorecard = pd.DataFrame(scorecard_rows).set_index("Predictor")
df_scorecard = df_scorecard.sort_values("Mean CRPS (2026)")

print("━" * 72)
print("2026 EVAL SCORECARD — STATELESS BASELINE:")
print("━" * 72)
print(df_scorecard.to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 2026 EVAL SCORECARD — STATELESS BASELINE:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                             Mean CRPS (2026)  MAE h=21d (2026)  80% CI Coverage
# Predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)          8.483507         11.252000             44.0
# AutoARIMA                                                           8.521366         10.422877             56.0
# CFM Agent v5.2                                                      8.976759         10.583428             44.0
# Naive (Last Value)                                                 10.489200         10.489200              0.0

# %% [markdown]
# ---
# ## 7. Diagnostics — reading past the leaderboard
#
# The scorecard above is a single number per method. That hides *where* the score
# comes from and *whether the ranking is even real*. The next cells decompose it
# straight from the eval predictions — so they recompute on any rerun, smoke or
# full:
#
# - **CRPS by horizon** — does a method win everywhere, or is its mean dominated by
#   one horizon? (For a short forecast, the 5-day calls are easy and nearly tied;
#   the ranking is usually decided by the longest horizon.)
# - **Mean CRPS ± standard error** — with only a handful of origins, are the gaps
#   between methods bigger than the noise, or is the "winner" a coin flip?
#
# With the **smoke spec (2 origins → a few scored points)** expect wide error bars
# and an unstable ranking. That is exactly why a surprising leaderboard here is not
# yet evidence of anything — it is a pipeline check.

# %%
from energy_oil_forecasting import viz
from energy_oil_forecasting.analysis import (
    build_price_frame,
    eval_narrative_md,
    extract_agent_rationales,
    leaderboard_with_uncertainty,
    per_horizon_crps,
    predictions_to_frame,
)
from IPython.display import HTML, Markdown, display  # noqa: A004


# Explode every scored 2026 eval prediction into one tidy row per
# (predictor, origin, horizon): point, 80% interval, realised price, and CRPS.
# Everything in Sections 7–10 reads from this frame, so it all recomputes when
# you flip SMOKE_TEST off and rerun.
price_df = build_price_frame(data_service)
eval_frame = predictions_to_frame(eval_results, data_service)
eval_board = leaderboard_with_uncertainty(eval_frame)
ph_crps = per_horizon_crps(eval_frame)

print("━" * 72)
print("MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):")
print("━" * 72)
print(ph_crps.round(2).to_string())
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# MEAN CRPS BY PREDICTOR × HORIZON (lower = better; 'All' = overall mean):
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#                                                              h=5d  h=10d  h=21d    All
# predictor
# News Agent Scenario Schema (gemini-3.1-flash-lite-preview)   7.34   5.21  12.17   8.48
# AutoARIMA                                                    8.30   5.57  11.04   8.52
# CFM Agent v5.2                                               8.51   6.12  11.66   8.98
# Naive (Last Value)                                          10.23   6.96  13.50  10.49

# %%
# Heatmap of the table above. Read it left-to-right: the short-horizon columns
# are usually a near-uniform green (everyone is right), and one long-horizon
# column carries the colour spread that sets the 'All' ranking.
viz.make_crps_heatmap(ph_crps)

# %%
# Same leaderboard, now with a standard-error bar on each mean. If the bars of
# the top methods overlap, their ordering is not statistically distinguishable —
# the honest verdict when only a few origins have been scored.
viz.make_leaderboard_interval_chart(eval_board)

# %% [markdown]
# ---
# ## 8. What are the top methods actually forecasting?
#
# A CRPS number doesn't show *behaviour*. Below, each leading method's **median
# forecast and 80% interval** are drawn against the realised WTI path at every
# eval origin. This is where the leaderboard becomes legible — watch for who
# tracks the move, who simply anchors to the last price, and whose intervals are
# too narrow to cover the outcome when the market jumps.

# %%
# Plot the leaderboard's top methods, and always include the best LLM/agent
# method for contrast (so the chart compares families even when a baseline leads).
_leaders = list(eval_board.index[:3])
_best_llm = next((p for p in eval_board.index if eval_board.loc[p, "family"] == "LLM / Agent"), None)
if _best_llm and _best_llm not in _leaders:
    _leaders.append(_best_llm)
print(f"Showing: {', '.join(_leaders)}")
viz.make_eval_forecast_chart(eval_frame, price_df, _leaders)
# Out:
# Showing: News Agent Scenario Schema (gemini-3.1-flash-lite-preview), AutoARIMA, CFM Agent v5.2
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a6f9d00>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9a117ee0>, 10416.760754874)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1dad7975f0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c1d9a078740>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x7c1d9bcebaf0>, 10406.979575617)])']
# connector: <aiohttp.connector.TCPConnector object at 0x7c1d9a0798e0>

# %% [markdown]
# ---
# ## 9. Reading the agent's reasoning
#
# The news-reading agent attaches a free-text **rationale** to every forecast, and
# a link to the full **Langfuse trace**. These are pulled straight from the
# prediction metadata. This is where a surprising score becomes interpretable: you
# can read whether the agent actually saw the geopolitical risk, and *how* it
# turned that into a price and an interval — including, often, an interval far too
# narrow for a regime shift.

# %%
# One card per (agent, origin): the rationale, the per-horizon note, and a link
# to the full reasoning trace. Empty only if no LLM/agent predictor is enabled.
eval_rationales = extract_agent_rationales(eval_results)
display(HTML(viz.render_rationales_html(eval_rationales)))
# Out:
# <div style='max-width:900px'><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-02 &nbsp; point $64.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/bc63ed8fb771f6c9b26502772a1e7e2f' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The market is currently caught between short-term supply constraints due to weather and geopolitical anxiety, and a longer-term concern regarding structural oversupply. The current price ($65.20) reflects a significant risk premium. The base case anticipates this premium will erode as physical supply recovers, while a tail case scenario captures the downside risk if the oversupply narrative dominates rapidly.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Over the next 5 business days, the market will likely digest the recent price surge. While geopolitical risks remain elevated, some profit-taking is expected as the immediate impacts of Winter Storm Fern begin to subside, leading to a consolidation near current levels.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-02-16 &nbsp; point $62.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/75635c5717766759f273dcb86301e28e' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The WTI market is currently navigating a fragile equilibrium. While geopolitical risk in the Middle East provides a significant floor, the market is increasingly focused on the looming prospect of OPEC+ returning volumes to the market. Structural demand concerns act as a persistent headwind, capping upside potential unless a significant supply-side disruption occurs.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Short-term stabilization near $62-$63 as the market digests recent gains, with geopolitical risk providing a support floor.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between'><b style='color:#1a1a1a'>News Agent Scenario Schema (gemini-3.1-flash-lite-preview)</b><span style='color:#888'>2026-03-02 &nbsp; point $74.5 &nbsp; <a href='https://us.cloud.langfuse.com/project/cmqqnxnbo0eu0ad0dz56jsohk/traces/31998e5a9faf4ebc5265ab84de6028ff' target='_blank' style='color:#2171b5'>🔗 Langfuse trace</a></span></div><div style='margin-top:6px;color:#333'>The WTI market is currently hyper-focused on the sudden geopolitical escalation following U.S.-Israeli strikes on Iran. My forecast incorporates a heavy risk premium that persists in the short term but exhibits massive uncertainty over the 21-day horizon, reflecting the binary nature of the conflict outcome: rapid cooling vs. significant blockade-driven supply shock.</div><div style='margin-top:6px;color:#444'><b>Horizon note:</b> Immediate price action is dominated by the recent military escalation in the Middle East. With the market reacting to potential threats to the Strait of Hormuz, volatility is elevated. We expect the risk premium to hold or expand over the next week as details of the conflict's impact on logistics unfold.</div></div><div style='border:1px solid #e0e0e0;border-radius:8px;padding:12px 14px;margin:8px 0;background:#fafafa;font-size:13px;line-height:1.5'><div style='display:flex;justify-content:space-between' ...

# %% [markdown]
# ---
# ## 10. Takeaways — computed from this run
#
# The summary below is **generated from the eval results in memory, not
# hard-coded**, so it always matches what actually ran: the real winner, whether
# its lead clears the noise floor, the horizon that decided the ranking, the
# best-performing family, and a calibration line. Flip `SMOKE_TEST` off, rerun,
# and these takeaways update themselves with the full leaderboard.

# %%
display(Markdown(eval_narrative_md(eval_frame, smoke=SMOKE_TEST)))
# Out:
# 1. **News Agent Scenario Schema (gemini-3.1-flash-lite-preview)** has the best mean CRPS (8.48) on the 2026 evaluation, ahead of **AutoARIMA** (8.52) by 0.04 — **well within the combined standard error**, so the ranking here is not statistically distinguishable from noise.
# 2. The leaderboard is **decided at h=21d**, where CRPS ranges 0.3–34.4 across methods; at the short h=10d horizon the methods are nearly tied (range 0.2–26.5). A handful of long-horizon points drives the whole ranking.
# 3. **By family** (mean CRPS): Numerical ML 8.52, LLM / Agent 8.73, Baseline 10.49. Best family this window: **Numerical ML**.
# 4. **Calibration:** News Agent Scenario Schema (gemini-3.1-flash-lite-preview)'s 80% interval covered 44% of outcomes (target 80%) over its 25 scored point(s). With this few, coverage this far from target is itself a small-sample artefact, not necessarily mis-calibration.
# 5. Based on 9 origins / 100 scored points.

# %% [markdown]
# ---
# ## 11. What stateless methods can't do
#
# Sections 7–10 score and dissect this run on its own terms. But every method here
# shares one structural limit, independent of who topped the leaderboard: it is
# calibrated (or prompted) **once and never updated between rounds**. That is
# intentional — it creates a clean baseline — but it leaves a systematic gap:
#
# - **No error feedback.** If a method's intervals are consistently too narrow in
#   an elevated-vol regime (read the coverage line in Section 10, and the squashed
#   error bars in Section 8), it keeps making the same mistake. Nothing updates its
#   calibration between origins.
#
# - **No strategy evolution.** Each prediction starts from the same prior — the
#   same fitted model, or the same prompt. Resolved outcomes disappear without
#   influencing future forecasts.
#
# - **Context without memory.** Even the news agent re-reads the world each origin;
#   it does not accumulate what worked. The rationales in Section 9 are written
#   fresh every time, with no record of how the last one resolved.
#
# → **Notebook 5** introduces adaptive agents that study the 2025 backtest, record
# systematic observations, and calibrate their strategies accordingly. At inference
# time, each agent receives the live stateless estimate and decides how to adjust
# it — applying what it learned from training.
#
# → **Notebook 6** evaluates whether any training approach actually improved
# out-of-sample performance on the held-out 2026 data — measured against the
# stateless baseline this notebook just established.

# %%
from aieng.forecasting.methods.agentic.agent_factory import ContextRetrievalConfig
print("verifier_model" in ContextRetrievalConfig.model_fields)
print(ContextRetrievalConfig.model_fields.keys())
# Out:
# True
# dict_keys(['enabled', 'search_model', 'instruction', 'enforce_cutoff', 'temperature', 'max_output_tokens', 'verifier_model', 'verifier_max_attempts', 'verifier_confidence_threshold'])

# %%
import glob, os, datetime
for path in glob.glob("**/data/predictions/**/*scenario_schema*", recursive=True):
    print(datetime.datetime.fromtimestamp(os.path.getmtime(path)), path)
# Out:
# 2026-07-25 16:59:50.483749 data/predictions/energy_oil_eval_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:06:56.632109 data/predictions/energy_oil_eval_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-07-25 16:48:08.773386 data/predictions/energy_oil_backtest_10yr_quarterly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:00:36.464605 data/predictions/energy_oil_backtest_biweekly_smoke/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 15:26:18.033594 data/predictions/energy_oil_backtest_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
# 2026-08-19 16:51:15.284929 data/predictions/energy_oil_eval_biweekly/agent_predictor_wti_analyst_news_scenario_schema_gemini-3.1-flash-lite-preview_continuous__wti_oil_price_forecast.yaml
